# %% [markdown]
# # GML Final Project Classification on bbbp Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install dgl -f https://data.dgl.ai/wheels/repo.html

# !pip install dglgo -f https://data.dgl.ai/wheels-test/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Collecting dgl
#   Downloading dgl-1.1.1-cp310-cp310-manylinux1_x86_64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.22.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (1.10.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.10/dist-packages (from dgl) (3.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dgl) (4.65.0)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from dgl) (5.9.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->dgl) (3.4)
# Installing collected packages: dgl
# Successfully installed dgl-1.1.1
# Looking in links: https://data.dgl.ai/wheels-test/repo.html
# Collecting dglgo
#   Downloading dglgo-0.0.2-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (0.7.0)
# Collecting isort>=5.10.1 (from dglgo)
#   Downloading isort-5.12.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.1 MB/s eta 0:00:00
# Collecting autopep8>=1.6.0 (from dglgo)
#   Downloading autopep8-2.0.2-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.5 MB/s eta 0:00:00
# Collecting numpydoc>=1.1.0 (from dglgo)
#   Downloading numpydoc-1.5.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (1.10.9)
# Collecting ruamel.yaml>=0.17.20 (from dglgo)
#   Downloading ruamel.yaml-0.17.32-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from dglgo) (6.0)
# Collecting ogb>=1.3.3 (from dglgo)
#   Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.9 MB/s eta 0:00:00
# Collecting rdkit-pypi (from dglgo)
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from dglgo) (1.2.2)
# Collecting pycodestyle>=2.10.0 (from autopep8>=1.6.0->dglgo)
#   Downloading pycodestyle-2.10.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from autopep8>=1.6.0->dglgo) (2.0.1)
# Collecting sphinx>=4.2 (from numpydoc>=1.1.0->dglgo)
#   Downloading sphinx-7.0.1-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 65.2 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=1.1.0->dglgo) (3.1.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.22.4)
# Requirement already satisfied: tqdm>=4.29.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (4.65.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.5.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from ogb>=1.3.3->dglgo) (1.26.16)
# Collecting outdated>=0.2.0 (from ogb>=1.3.3->dglgo)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.0->dglgo) (4.6.3)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.20->dglgo)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 39.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->dglgo) (3.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.4.0->dglgo) (8.1.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi->dglgo) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.10->numpydoc>=1.1.0->dglgo) (2.1.3)
# Requirement already satisfied: setuptools>=44 in /usr/local/lib/python3.10/dist-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (67.7.2)
# Collecting littleutils (from outdated>=0.2.0->ogb>=1.3.3->dglgo)
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2022.7.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.4)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.3)
# Requirement already satisfied: Pygments>=2.13 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.14.0)
# Collecting docutils<0.21,>=0.18.1 (from sphinx>=4.2->numpydoc>=1.1.0->dglgo)
#   Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 kB 42.9 MB/s eta 0:00:00
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.12.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (0.7.13)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.4.1)
# Requirement already satisfied: packaging>=21.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->ogb>=1.3.3->dglgo) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->ogb>=1.3.3->dglgo) (16.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->outdated>=0.2.0->ogb>=1.3.3->dglgo) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->ogb>=1.3.3->dglgo) (1.3.0)
# Building wheels for collected packages: littleutils
#   Building wheel for littleutils (setup.py) ... done
#   Created wheel for littleutils: filename=littleutils-0.2.2-py3-none-any.whl size=7029 sha256=527f93a7f2d0159b0eeef3f97ec633f2cb491d5bb202c9d4529b7e3813a5b350
#   Stored in directory: /root/.cache/pip/wheels/3d/fe/b0/27a9892da57472e538c7452a721a9cf463cc03cf7379889266
# Successfully built littleutils
# Installing collected packages: littleutils, ruamel.yaml.clib, rdkit-pypi, pycodestyle, isort, docutils, sphinx, ruamel.yaml, outdated, autopep8, numpydoc, ogb, dglgo
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 3.5.4
#     Uninstalling Sphinx-3.5.4:
#       Successfully uninstalled Sphinx-3.5.4
# Successfully installed autopep8-2.0.2 dglgo-0.0.2 docutils-0.20.1 isort-5.12.0 littleutils-0.2.2 numpydoc-1.5.0 ogb-1.3.6 outdated-0.2.2 pycodestyle-2.10.0 rdkit-pypi-2022.9.5 ruamel.yaml-0.17.32 ruamel.yaml.clib-0.2.7 sphinx-7.0.1

# %%
# %matplotlib inline
import os

os.environ["DGLBACKEND"] = "pytorch"
import dgl
import numpy as np
import networkx as nx
import torch
import torch.nn as nn
import dgl.function as fn
import torch.nn.functional as F
import shutil
from torch.utils.data import DataLoader
import cloudpickle
from dgl.nn import GraphConv

# %% [markdown]
# #### Set Path

# %%
current_dir = "/content/drive/MyDrive/GML Final Project/"
checkpoint_path = current_dir + "save_models/model_checkpoints/" + "checkpoint"
os.makedirs(checkpoint_path, exist_ok=True)

best_model_path = current_dir + "save_models/best_model/"

folder_data_temp = current_dir +"data_temp/"
shutil.rmtree(folder_data_temp, ignore_errors=True)

path_save = current_dir + "Hierarchical_Quotient_type_False_Both_False_Uni_Vert_False_#quotient_2_#layers_1_127_one_hot.zip"
shutil.unpack_archive(path_save, folder_data_temp)

# %% [markdown]
# #### Custom PyTorch Datasets

# %%
""" Classification Dataset """
class DGLDatasetClass(torch.utils.data.Dataset):
    def __init__(self, address):
            self.address=address+".bin"
            self.list_graphs, train_labels_globals = dgl.load_graphs(self.address)
            num_graphs =len(self.list_graphs)
            self.labels = train_labels_globals["labels"]
            self.globals = train_labels_globals["globals"]

    def __len__(self):
        return len(self.list_graphs)

    def __getitem__(self, idx):
        return  self.list_graphs[idx], self.labels[idx], self.globals[idx]

# %% [markdown]
# #### Defining Train, Validation, and Test Set

# %%
path_data_temp = folder_data_temp + "scaffold"+"_"+str(2)
train_set = DGLDatasetClass(address=path_data_temp+"_train")
val_set = DGLDatasetClass(address=path_data_temp+"_val")
test_set = DGLDatasetClass(address=path_data_temp+"_test")

print(len(train_set), len(val_set), len(test_set))
# Out:
# 1631 203 205

# %% [markdown]
# #### Data Loader

# %%
def collate(batch):
    # batch is a list of tuples (graphs, labels, globals)
    # Concatenate a sequence of graphs
    graphs = [e[0] for e in batch]
    g = dgl.batch(graphs)

    # Concatenate a sequence of tensors (labels) along a new dimension
    labels = [e[1] for e in batch]
    labels = torch.stack(labels, 0)

    # Concatenate a sequence of tensors (globals) along a new dimension
    globals = [e[2] for e in batch]
    globals = torch.stack(globals, 0)

    return g, labels, globals


def loader(batch_size=64):
    train_dataloader = DataLoader(train_set,
                              batch_size=batch_size,
                              collate_fn=collate,
                              drop_last=True,
                              shuffle=True,
                              num_workers=1)

    val_dataloader =  DataLoader(val_set,
                             batch_size=batch_size,
                             collate_fn=collate,
                             drop_last=True,
                             shuffle=False,
                             num_workers=1)

    test_dataloader = DataLoader(test_set,
                             batch_size=batch_size,
                             collate_fn=collate,
                             drop_last=True,
                             shuffle=False,
                             num_workers=1)
    return train_dataloader, val_dataloader, test_dataloader

# %%
train_dataloader, val_dataloader, test_dataloader = loader(batch_size=64)

# %% [markdown]
# #### Defining A GNN

# %% [markdown]
# ##### Some Variables

# %%
#Bace dataset has 1 task. Some other datasets may have some more number of tasks, e.g., tox21 has 12 tasks.
num_tasks = 1

# Size of global feature of each graph
global_size = 200

# Number of epochs to train the model
num_epochs = 100

# Number of steps to wait if the model performance on the validation set does not improve
patience = 10

#Configurations to instantiate the model
config = {"node_feature_size":127, "edge_feature_size":12, "hidden_size":100}

# %% [markdown]
# # innovated module 1

# %%
dgl.use_libxsmm(False)

class CustomModule(nn.Module):
    def __init__(self, in_feat, out_feat):
        super(CustomModule, self).__init__()

        self.linear1 = nn.Linear(in_feat * 2, 256)
        self.linear2 = nn.Linear(256, out_feat)
        self.relu = nn.ReLU()

    def forward(self, g, h):
        with g.local_scope():
            g.ndata["h"] = h
            g.update_all(
                message_func=fn.copy_u('h', 'm'),
                reduce_func=fn.max("m", "A"),
            )
            A = g.ndata["A"]
            concat = torch.cat([h, A], dim=1)
            output = self.linear1(concat)
            output = self.relu(output)
            output = self.linear2(output)
            output = self.relu(output)
            return output

# %%
class GNN(nn.Module):
    def __init__(self, config, global_size=200):
        super().__init__()
        self.config = config


        # Node feature size
        self.node_feature_size = self.config.get('node_feature_size', 127)

        # Edge feature size
        self.edge_feature_size = self.config.get('edge_feature_size', 12)

        # Hidden size
        self.hidden_size = self.config.get('hidden_size', 100)

        self.Custom1 = CustomModule(self.node_feature_size, self.hidden_size)
        self.Custom2 = CustomModule(self.hidden_size, self.hidden_size)
        self.Custom3 = CustomModule(self.hidden_size, self.hidden_size)
        self.Custom4 = CustomModule(self.hidden_size, 1)

    def forward(self, mol_dgl_graph, globals):
        mol_dgl_graph.ndata["v"] = mol_dgl_graph.ndata["v"][:, :self.node_feature_size]
        mol_dgl_graph.edata["e"] = mol_dgl_graph.edata["e"][:, :self.edge_feature_size]

        h = mol_dgl_graph.ndata["v"]
        h = self.Custom1(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom2(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom3(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom4(mol_dgl_graph, h)
        mol_dgl_graph.ndata["h"] = h
        return dgl.mean_nodes(mol_dgl_graph, "h")

# %%
from sklearn.metrics import roc_auc_score

def compute_score(model, data_loader, val_size):
    model.eval()
    metric = roc_auc_score
    with torch.no_grad():
        prediction_all= torch.empty(0)
        labels_all= torch.empty(0)
        for i, (mol_dgl_graph, labels, globals) in enumerate(data_loader):
            prediction = model(mol_dgl_graph, globals)
            prediction = torch.sigmoid(prediction)
            prediction_all = torch.cat((prediction_all, prediction), 0)
            labels_all = torch.cat((labels_all, labels), 0)
        average = torch.tensor([0.])
        for i in range(num_tasks):
            a1 = prediction_all[:, i]
            a2 = labels_all[:, i]
            try:
                t = metric(a2.int().cpu(), a1.cpu()).item()
            except ValueError:
                t = 0
            average += t
    return average.item()

# %%
def loss_func(output, label):
    criterion = torch.nn.BCEWithLogitsLoss(reduction='mean')
    loss = criterion(output, label)
    return loss

# %%
def train_epoch(train_dataloader, model, optimizer):
    epoch_train_loss = 0
    iterations = 0
    model.train()
    for i, (mol_dgl_graph, labels, globals) in enumerate(train_dataloader):
        prediction = model(mol_dgl_graph, globals)
        loss_train = loss_func(prediction, labels)
        optimizer.zero_grad(set_to_none=True)
        loss_train.backward()
        optimizer.step()
        epoch_train_loss += loss_train.detach().item()
        iterations += 1
    epoch_train_loss /= iterations
    return epoch_train_loss

# %%
def train_evaluate():

    model = GNN(config, global_size)
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)

    best_val = 0
    patience_count = 1
    epoch = 1

    while epoch <= num_epochs:
        if patience_count <= patience:
            model.train()
            loss_train = train_epoch(train_dataloader, model, optimizer)
            model.eval()
            score_val = compute_score(model, val_dataloader, len(val_set))
            if score_val > best_val:
                best_val = score_val
                print("Save checkpoint")
                path = os.path.join(checkpoint_path, 'checkpoint.pth')
                dict_checkpoint = {"score_val": score_val}
                dict_checkpoint.update({"model_state_dict": model.state_dict(), "optimizer_state": optimizer.state_dict()})
                with open(path, "wb") as outputfile:
                    cloudpickle.dump(dict_checkpoint, outputfile)
                patience_count = 1
            else:
                print("Patience", patience_count)
                patience_count += 1

            print("Epoch: {}/{} | Training Loss: {:.3f} | Valid Score: {:.3f}".format(
            epoch, num_epochs, loss_train, score_val))

            print(" ")
            print("Epoch: {}/{} | Best Valid Score Until Now: {:.3f}".format(epoch, num_epochs, best_val), "\n")
        epoch += 1

    # best model save
    shutil.rmtree(best_model_path, ignore_errors=True)
    shutil.copytree(checkpoint_path, best_model_path)

    print("Final results:")
    print("Average Valid Score: {:.3f}".format(np.mean(best_val)), "\n")

# %%
def test_evaluate():
    final_model = GNN(config, global_size)
    path = os.path.join(best_model_path, 'checkpoint.pth')
    with open(path, 'rb') as f:
        checkpoint = cloudpickle.load(f)
    final_model.load_state_dict(checkpoint["model_state_dict"])
    final_model.eval()
    test_score = compute_score(final_model, test_dataloader, len(test_set))

    print("Test Score: {:.3f}".format(test_score), "\n")
    print("Execution time: {:.3f} seconds".format(time.time() - start_time))

# %%
import time
start_time = time.time()

train_evaluate()
test_evaluate()
# Out:
# Save checkpoint
# Epoch: 1/100 | Training Loss: 0.681 | Valid Score: 0.465
#
# Epoch: 1/100 | Best Valid Score Until Now: 0.465
#
# Patience 1
# Epoch: 2/100 | Training Loss: 0.641 | Valid Score: 0.446
#
# Epoch: 2/100 | Best Valid Score Until Now: 0.465
#
# Patience 2
# Epoch: 3/100 | Training Loss: 0.590 | Valid Score: 0.452
#
# Epoch: 3/100 | Best Valid Score Until Now: 0.465
#
# Save checkpoint
# Epoch: 4/100 | Training Loss: 0.575 | Valid Score: 0.492
#
# Epoch: 4/100 | Best Valid Score Until Now: 0.492
#
# Save checkpoint
# Epoch: 5/100 | Training Loss: 0.556 | Valid Score: 0.650
#
# Epoch: 5/100 | Best Valid Score Until Now: 0.650
#
# Patience 1
# Epoch: 6/100 | Training Loss: 0.532 | Valid Score: 0.622
#
# Epoch: 6/100 | Best Valid Score Until Now: 0.650
#
# Save checkpoint
# Epoch: 7/100 | Training Loss: 0.501 | Valid Score: 0.656
#
# Epoch: 7/100 | Best Valid Score Until Now: 0.656
#
# Save checkpoint
# Epoch: 8/100 | Training Loss: 0.476 | Valid Score: 0.687
#
# Epoch: 8/100 | Best Valid Score Until Now: 0.687
#
# Save checkpoint
# Epoch: 9/100 | Training Loss: 0.454 | Valid Score: 0.731
#
# Epoch: 9/100 | Best Valid Score Until Now: 0.731
#
# Save checkpoint
# Epoch: 10/100 | Training Loss: 0.441 | Valid Score: 0.748
#
# Epoch: 10/100 | Best Valid Score Until Now: 0.748
#
# Save checkpoint
# Epoch: 11/100 | Training Loss: 0.434 | Valid Score: 0.758
#
# Epoch: 11/100 | Best Valid Score Until Now: 0.758
#
# Save checkpoint
# Epoch: 12/100 | Training Loss: 0.426 | Valid Score: 0.776
#
# Epoch: 12/100 | Best Valid Score Until Now: 0.776
#
# Save checkpoint
# Epoch: 13/100 | Training Loss: 0.422 | Valid Score: 0.779
#
# Epoch: 13/100 | Best Valid Score Until Now: 0.779
#
# Save checkpoint
# Epoch: 14/100 | Training Loss: 0.418 | Valid Score: 0.794
#
# Epoch: 14/100 | Best Valid Score Until Now: 0.794
#
# Save checkpoint
# Epoch: 15/100 | Training Loss: 0.412 | Valid Score: 0.798
#
# Epoch: 15/100 | Best Valid Score Until Now: 0.798
#
# Save checkpoint
# Epoch: 16/100 | Training Loss: 0.415 | Valid Score: 0.805
#
# Epoch: 16/100 | Best Valid Score Until Now: 0.805
#
# Save checkpoint
# Epoch: 17/100 | Training Loss: 0.408 | Valid Score: 0.815
#
# Epoch: 17/100 | Best Valid Score Until Now: 0.815
#
# Patience 1
# Epoch: 18/100 | Training Loss: 0.418 | Valid Score: 0.804
#
# Epoch: 18/100 | Best Valid Score Until Now: 0.815
#
# Save checkpoint
# Epoch: 19/100 | Training Loss: 0.404 | Valid Score: 0.820
#
# Epoch: 19/100 | Best Valid Score Until Now: 0.820
#
# Save checkpoint
# Epoch: 20/100 | Training Loss: 0.402 | Valid Score: 0.828
#
# Epoch: 20/100 | Best Valid Score Until Now: 0.828
#
# Save checkpoint
# Epoch: 21/100 | Training Loss: 0.392 | Valid Score: 0.830
#
# Epoch: 21/100 | Best Valid Score Until Now: 0.830
#
# Save checkpoint
# Epoch: 22/100 | Training Loss: 0.390 | Valid Score: 0.833
#
# Epoch: 22/100 | Best Valid Score Until Now: 0.833
#
# Save checkpoint
# Epoch: 23/100 | Training Loss: 0.389 | Valid Score: 0.836
#
# Epoch: 23/100 | Best Valid Score Until Now: 0.836
#
# Patience 1
# Epoch: 24/100 | Training Loss: 0.388 | Valid Score: 0.836
#
# Epoch: 24/100 | Best Valid Score Until Now: 0.836
#
# Save checkpoint
# Epoch: 25/100 | Training Loss: 0.389 | Valid Score: 0.837
#
# Epoch: 25/100 | Best Valid Score Until Now: 0.837
#
# Patience 1
# Epoch: 26/100 | Training Loss: 0.388 | Valid Score: 0.836
#
# Epoch: 26/100 | Best Valid Score Until Now: 0.837
#
# Patience 2
# Epoch: 27/100 | Training Loss: 0.381 | Valid Score: 0.835
#
# Epoch: 27/100 | Best Valid Score Until Now: 0.837
#
# Save checkpoint
# Epoch: 28/100 | Training Loss: 0.377 | Valid Score: 0.840
#
# Epoch: 28/100 | Best Valid Score Until Now: 0.840
#
# Patience 1
# Epoch: 29/100 | Training Loss: 0.383 | Valid Score: 0.839
#
# Epoch: 29/100 | Best Valid Score Until Now: 0.840
#
# Save checkpoint
# Epoch: 30/100 | Training Loss: 0.379 | Valid Score: 0.847
#
# Epoch: 30/100 | Best Valid Score Until Now: 0.847
#
# Save checkpoint
# Epoch: 31/100 | Training Loss: 0.378 | Valid Score: 0.853
#
# Epoch: 31/100 | Best Valid Score Until Now: 0.853
#
# Patience 1
# Epoch: 32/100 | Training Loss: 0.367 | Valid Score: 0.849
#
# Epoch: 32/100 | Best Valid Score Until Now: 0.853
#
# Patience 2
# Epoch: 33/100 | Training Loss: 0.369 | Valid Score: 0.850
#
# Epoch: 33/100 | Best Valid Score Until Now: 0.853
#
# Patience 3
# Epoch: 34/100 | Training Loss: 0.365 | Valid Score: 0.849
#
# Epoch: 34/100 | Best Valid Score Until Now: 0.853
#
# Save checkpoint
# Epoch: 35/100 | Training Loss: 0.363 | Valid Score: 0.855
#
# Epoch: 35/100 | Best Valid Score Until Now: 0.855
#
# Save checkpoint
# Epoch: 36/100 | Training Loss: 0.357 | Valid Score: 0.857
#
# Epoch: 36/100 | Best Valid Score Until Now: 0.857
#
# Patience 1
# Epoch: 37/100 | Training Loss: 0.358 | Valid Score: 0.846
#
# Epoch: 37/100 | Best Valid Score Until Now: 0.857
#
# Patience 2
# Epoch: 38/100 | Training Loss: 0.358 | Valid Score: 0.856
#
# Epoch: 38/100 | Best Valid Score Until Now: 0.857
#
# Patience 3
# Epoch: 39/100 | Training Loss: 0.357 | Valid Score: 0.853
#
# Epoch: 39/100 | Best Valid Score Until Now: 0.857
#
# Save checkpoint
# Epoch: 40/100 | Training Loss: 0.359 | Valid Score: 0.859
#
# Epoch: 40/100 | Best Valid Score Until Now: 0.859
#
# Patience 1
# Epoch: 41/100 | Training Loss: 0.354 | Valid Score: 0.859
#
# Epoch: 41/100 | Best Valid Score Until Now: 0.859
#
# Patience 2
# Epoch: 42/100 | Training Loss: 0.362 | Valid Score: 0.858
#
# Epoch: 42/100 | Best Valid Score Until Now: 0.859
#
# Save checkpoint
# Epoch: 43/100 | Training Loss: 0.347 | Valid Score: 0.861
#
# Epoch: 43/100 | Best Valid Score Until Now: 0.861
#
# Patience 1
# Epoch: 44/100 | Training Loss: 0.351 | Valid Score: 0.861
#
# Epoch: 44/100 | Best Valid Score Until Now: 0.861
#
# Patience 2
# Epoch: 45/100 | Training Loss: 0.340 | Valid Score: 0.861
#
# Epoch: 45/100 | Best Valid Score Until Now: 0.861
#
# Patience 3
# Epoch: 46/100 | Training Loss: 0.337 | Valid Score: 0.860
#
# Epoch: 46/100 | Best Valid Score Until Now: 0.861
#
# Save checkpoint
# Epoch: 47/100 | Training Loss: 0.333 | Valid Score: 0.863
#
# Epoch: 47/100 | Best Valid Score Until Now: 0.863
#
# Save checkpoint
# Epoch: 48/100 | Training Loss: 0.337 | Valid Score: 0.864
#
# Epoch: 48/100 | Best Valid Score Until Now: 0.864
#
# Patience 1
# Epoch: 49/100 | Training Loss: 0.337 | Valid Score: 0.863
#
# Epoch: 49/100 | Best Valid Score Until Now: 0.864
#
# Save checkpoint
# Epoch: 50/100 | Training Loss: 0.338 | Valid Score: 0.865
#
# Epoch: 50/100 | Best Valid Score Until Now: 0.865
#
# Patience 1
# Epoch: 51/100 | Training Loss: 0.343 | Valid Score: 0.857
#
# Epoch: 51/100 | Best Valid Score Until Now: 0.865
#
# Patience 2
# Epoch: 52/100 | Training Loss: 0.323 | Valid Score: 0.858
#
# Epoch: 52/100 | Best Valid Score Until Now: 0.865
#
# Patience 3
# Epoch: 53/100 | Training Loss: 0.317 | Valid Score: 0.863
#
# Epoch: 53/100 | Best Valid Score Until Now: 0.865
#
# Patience 4
# Epoch: 54/100 | Training Loss: 0.322 | Valid Score: 0.860
#
# Epoch: 54/100 | Best Valid Score Until Now: 0.865
#
# Patience 5
# Epoch: 55/100 | Training Loss: 0.318 | Valid Score: 0.860
#
# Epoch: 55/100 | Best Valid Score Until Now: 0.865
#
# Patience 6
# Epoch: 56/100 | Training Loss: 0.318 | Valid Score: 0.862
#
# Epoch: 56/100 | Best Valid Score Until Now: 0.865
#
# Patience 7
# Epoch: 57/100 | Training Loss: 0.315 | Valid Score: 0.861
#
# Epoch: 57/100 | Best Valid Score Until Now: 0.865
#
# Patience 8
# Epoch: 58/100 | Training Loss: 0.317 | Valid Score: 0.860
#
# Epoch: 58/100 | Best Valid Score Until Now: 0.865
#
# Patience 9
# Epoch: 59/100 | Training Loss: 0.319 | Valid Score: 0.858
#
# Epoch: 59/100 | Best Valid Score Until Now: 0.865
#
# Patience 10
# Epoch: 60/100 | Training Loss: 0.313 | Valid Score: 0.859
#
# Epoch: 60/100 | Best Valid Score Until Now: 0.865
#
# Final results:
# Average Valid Score: 0.865
#
# Test Score: 0.762
#
# Execution time: 94.818 seconds

# %% [markdown]
# # innovated module 2

# %%
class CustomModule(nn.Module):
    def __init__(self, in_feat, out_feat):
        super(CustomModule, self).__init__()

        self.linear1 = nn.Linear(in_feat * 2, 256)
        self.linear2 = nn.Linear(256, out_feat)
        self.relu = nn.ReLU()

    def forward(self, g, h):
        with g.local_scope():
            g.ndata["h"] = h
            g.update_all(
                message_func=fn.v_mul_u('h', 'h', 'm'),
                reduce_func=fn.max("m", "A"),
            )
            A = g.ndata["A"]
            concat = torch.cat([h, A], dim=1)
            output = self.linear1(concat)
            output = self.relu(output)
            output = self.linear2(output)
            output = self.relu(output)
            return output

# %%
class GNN(nn.Module):
    def __init__(self, config, global_size=200):
        super().__init__()
        self.config = config


        # Node feature size
        self.node_feature_size = self.config.get('node_feature_size', 127)

        # Edge feature size
        self.edge_feature_size = self.config.get('edge_feature_size', 12)

        # Hidden size
        self.hidden_size = self.config.get('hidden_size', 100)

        self.Custom1 = CustomModule(self.node_feature_size, self.hidden_size)
        self.Custom2 = CustomModule(self.hidden_size, self.hidden_size)
        self.Custom3 = CustomModule(self.hidden_size, self.hidden_size)
        self.Custom4 = CustomModule(self.hidden_size, 1)

    def forward(self, mol_dgl_graph, globals):
        mol_dgl_graph.ndata["v"] = mol_dgl_graph.ndata["v"][:, :self.node_feature_size]
        mol_dgl_graph.edata["e"] = mol_dgl_graph.edata["e"][:, :self.edge_feature_size]

        h = mol_dgl_graph.ndata["v"]
        h = self.Custom1(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom2(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom3(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom4(mol_dgl_graph, h)
        mol_dgl_graph.ndata["h"] = h
        return dgl.mean_nodes(mol_dgl_graph, "h")

# %%
import time
start_time = time.time()

train_evaluate()
test_evaluate()
# Out:
# Save checkpoint
# Epoch: 1/100 | Training Loss: 0.678 | Valid Score: 0.438
#
# Epoch: 1/100 | Best Valid Score Until Now: 0.438
#
# Patience 1
# Epoch: 2/100 | Training Loss: 0.664 | Valid Score: 0.425
#
# Epoch: 2/100 | Best Valid Score Until Now: 0.438
#
# Patience 2
# Epoch: 3/100 | Training Loss: 0.634 | Valid Score: 0.431
#
# Epoch: 3/100 | Best Valid Score Until Now: 0.438
#
# Save checkpoint
# Epoch: 4/100 | Training Loss: 0.552 | Valid Score: 0.594
#
# Epoch: 4/100 | Best Valid Score Until Now: 0.594
#
# Save checkpoint
# Epoch: 5/100 | Training Loss: 0.537 | Valid Score: 0.627
#
# Epoch: 5/100 | Best Valid Score Until Now: 0.627
#
# Save checkpoint
# Epoch: 6/100 | Training Loss: 0.525 | Valid Score: 0.641
#
# Epoch: 6/100 | Best Valid Score Until Now: 0.641
#
# Patience 1
# Epoch: 7/100 | Training Loss: 0.512 | Valid Score: 0.635
#
# Epoch: 7/100 | Best Valid Score Until Now: 0.641
#
# Save checkpoint
# Epoch: 8/100 | Training Loss: 0.500 | Valid Score: 0.666
#
# Epoch: 8/100 | Best Valid Score Until Now: 0.666
#
# Save checkpoint
# Epoch: 9/100 | Training Loss: 0.488 | Valid Score: 0.679
#
# Epoch: 9/100 | Best Valid Score Until Now: 0.679
#
# Patience 1
# Epoch: 10/100 | Training Loss: 0.472 | Valid Score: 0.677
#
# Epoch: 10/100 | Best Valid Score Until Now: 0.679
#
# Save checkpoint
# Epoch: 11/100 | Training Loss: 0.460 | Valid Score: 0.702
#
# Epoch: 11/100 | Best Valid Score Until Now: 0.702
#
# Patience 1
# Epoch: 12/100 | Training Loss: 0.462 | Valid Score: 0.690
#
# Epoch: 12/100 | Best Valid Score Until Now: 0.702
#
# Patience 2
# Epoch: 13/100 | Training Loss: 0.453 | Valid Score: 0.695
#
# Epoch: 13/100 | Best Valid Score Until Now: 0.702
#
# Patience 3
# Epoch: 14/100 | Training Loss: 0.450 | Valid Score: 0.689
#
# Epoch: 14/100 | Best Valid Score Until Now: 0.702
#
# Patience 4
# Epoch: 15/100 | Training Loss: 0.444 | Valid Score: 0.696
#
# Epoch: 15/100 | Best Valid Score Until Now: 0.702
#
# Patience 5
# Epoch: 16/100 | Training Loss: 0.447 | Valid Score: 0.692
#
# Epoch: 16/100 | Best Valid Score Until Now: 0.702
#
# Patience 6
# Epoch: 17/100 | Training Loss: 0.442 | Valid Score: 0.696
#
# Epoch: 17/100 | Best Valid Score Until Now: 0.702
#
# Patience 7
# Epoch: 18/100 | Training Loss: 0.433 | Valid Score: 0.692
#
# Epoch: 18/100 | Best Valid Score Until Now: 0.702
#
# Patience 8
# Epoch: 19/100 | Training Loss: 0.433 | Valid Score: 0.689
#
# Epoch: 19/100 | Best Valid Score Until Now: 0.702
#
# Patience 9
# Epoch: 20/100 | Training Loss: 0.436 | Valid Score: 0.684
#
# Epoch: 20/100 | Best Valid Score Until Now: 0.702
#
# Patience 10
# Epoch: 21/100 | Training Loss: 0.430 | Valid Score: 0.683
#
# Epoch: 21/100 | Best Valid Score Until Now: 0.702
#
# Final results:
# Average Valid Score: 0.702
#
# Test Score: 0.731
#
# Execution time: 37.149 seconds

# %% [markdown]
# # innovated module 3

# %%
class CustomModule(nn.Module):
    def __init__(self, in_feat, out_feat):
        super(CustomModule, self).__init__()

        self.linear1 = nn.Linear(in_feat * 2, 256)
        self.linear2 = nn.Linear(256, out_feat)
        self.relu = nn.ReLU()

    def forward(self, g, h):
        with g.local_scope():
            g.ndata["h"] = h
            g.update_all(
                message_func=fn.v_add_u('h', 'h', 'm'),
                reduce_func=fn.max("m", "A"),
            )
            A = g.ndata["A"]
            concat = torch.cat([h, A], dim=1)
            output = self.linear1(concat)
            output = self.relu(output)
            output = self.linear2(output)
            output = self.relu(output)
            return output

# %%
class GNN(nn.Module):
    def __init__(self, config, global_size=200):
        super().__init__()
        self.config = config


        # Node feature size
        self.node_feature_size = self.config.get('node_feature_size', 127)

        # Edge feature size
        self.edge_feature_size = self.config.get('edge_feature_size', 12)

        # Hidden size
        self.hidden_size = self.config.get('hidden_size', 100)

        self.Custom1 = CustomModule(self.node_feature_size, self.hidden_size)
        self.Custom2 = CustomModule(self.hidden_size, self.hidden_size)
        self.Custom3 = CustomModule(self.hidden_size, self.hidden_size)
        self.Custom4 = CustomModule(self.hidden_size, 1)

    def forward(self, mol_dgl_graph, globals):
        mol_dgl_graph.ndata["v"] = mol_dgl_graph.ndata["v"][:, :self.node_feature_size]
        mol_dgl_graph.edata["e"] = mol_dgl_graph.edata["e"][:, :self.edge_feature_size]

        h = mol_dgl_graph.ndata["v"]
        h = self.Custom1(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom2(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom3(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.Custom4(mol_dgl_graph, h)
        mol_dgl_graph.ndata["h"] = h
        return dgl.mean_nodes(mol_dgl_graph, "h")

# %%
import time
start_time = time.time()

train_evaluate()
test_evaluate()
# Out:
# Save checkpoint
# Epoch: 1/100 | Training Loss: 0.658 | Valid Score: 0.451
#
# Epoch: 1/100 | Best Valid Score Until Now: 0.451
#
# Save checkpoint
# Epoch: 2/100 | Training Loss: 0.601 | Valid Score: 0.452
#
# Epoch: 2/100 | Best Valid Score Until Now: 0.452
#
# Save checkpoint
# Epoch: 3/100 | Training Loss: 0.570 | Valid Score: 0.567
#
# Epoch: 3/100 | Best Valid Score Until Now: 0.567
#
# Save checkpoint
# Epoch: 4/100 | Training Loss: 0.538 | Valid Score: 0.641
#
# Epoch: 4/100 | Best Valid Score Until Now: 0.641
#
# Patience 1
# Epoch: 5/100 | Training Loss: 0.498 | Valid Score: 0.631
#
# Epoch: 5/100 | Best Valid Score Until Now: 0.641
#
# Save checkpoint
# Epoch: 6/100 | Training Loss: 0.475 | Valid Score: 0.697
#
# Epoch: 6/100 | Best Valid Score Until Now: 0.697
#
# Save checkpoint
# Epoch: 7/100 | Training Loss: 0.458 | Valid Score: 0.717
#
# Epoch: 7/100 | Best Valid Score Until Now: 0.717
#
# Save checkpoint
# Epoch: 8/100 | Training Loss: 0.448 | Valid Score: 0.733
#
# Epoch: 8/100 | Best Valid Score Until Now: 0.733
#
# Save checkpoint
# Epoch: 9/100 | Training Loss: 0.444 | Valid Score: 0.750
#
# Epoch: 9/100 | Best Valid Score Until Now: 0.750
#
# Save checkpoint
# Epoch: 10/100 | Training Loss: 0.442 | Valid Score: 0.780
#
# Epoch: 10/100 | Best Valid Score Until Now: 0.780
#
# Save checkpoint
# Epoch: 11/100 | Training Loss: 0.427 | Valid Score: 0.810
#
# Epoch: 11/100 | Best Valid Score Until Now: 0.810
#
# Patience 1
# Epoch: 12/100 | Training Loss: 0.426 | Valid Score: 0.809
#
# Epoch: 12/100 | Best Valid Score Until Now: 0.810
#
# Save checkpoint
# Epoch: 13/100 | Training Loss: 0.422 | Valid Score: 0.821
#
# Epoch: 13/100 | Best Valid Score Until Now: 0.821
#
# Patience 1
# Epoch: 14/100 | Training Loss: 0.416 | Valid Score: 0.813
#
# Epoch: 14/100 | Best Valid Score Until Now: 0.821
#
# Save checkpoint
# Epoch: 15/100 | Training Loss: 0.417 | Valid Score: 0.831
#
# Epoch: 15/100 | Best Valid Score Until Now: 0.831
#
# Patience 1
# Epoch: 16/100 | Training Loss: 0.422 | Valid Score: 0.825
#
# Epoch: 16/100 | Best Valid Score Until Now: 0.831
#
# Patience 2
# Epoch: 17/100 | Training Loss: 0.403 | Valid Score: 0.829
#
# Epoch: 17/100 | Best Valid Score Until Now: 0.831
#
# Save checkpoint
# Epoch: 18/100 | Training Loss: 0.398 | Valid Score: 0.837
#
# Epoch: 18/100 | Best Valid Score Until Now: 0.837
#
# Patience 1
# Epoch: 19/100 | Training Loss: 0.400 | Valid Score: 0.835
#
# Epoch: 19/100 | Best Valid Score Until Now: 0.837
#
# Save checkpoint
# Epoch: 20/100 | Training Loss: 0.395 | Valid Score: 0.840
#
# Epoch: 20/100 | Best Valid Score Until Now: 0.840
#
# Save checkpoint
# Epoch: 21/100 | Training Loss: 0.403 | Valid Score: 0.841
#
# Epoch: 21/100 | Best Valid Score Until Now: 0.841
#
# Save checkpoint
# Epoch: 22/100 | Training Loss: 0.389 | Valid Score: 0.846
#
# Epoch: 22/100 | Best Valid Score Until Now: 0.846
#
# Save checkpoint
# Epoch: 23/100 | Training Loss: 0.381 | Valid Score: 0.846
#
# Epoch: 23/100 | Best Valid Score Until Now: 0.846
#
# Patience 1
# Epoch: 24/100 | Training Loss: 0.386 | Valid Score: 0.843
#
# Epoch: 24/100 | Best Valid Score Until Now: 0.846
#
# Patience 2
# Epoch: 25/100 | Training Loss: 0.386 | Valid Score: 0.832
#
# Epoch: 25/100 | Best Valid Score Until Now: 0.846
#
# Patience 3
# Epoch: 26/100 | Training Loss: 0.380 | Valid Score: 0.845
#
# Epoch: 26/100 | Best Valid Score Until Now: 0.846
#
# Save checkpoint
# Epoch: 27/100 | Training Loss: 0.371 | Valid Score: 0.854
#
# Epoch: 27/100 | Best Valid Score Until Now: 0.854
#
# Patience 1
# Epoch: 28/100 | Training Loss: 0.360 | Valid Score: 0.847
#
# Epoch: 28/100 | Best Valid Score Until Now: 0.854
#
# Patience 2
# Epoch: 29/100 | Training Loss: 0.409 | Valid Score: 0.838
#
# Epoch: 29/100 | Best Valid Score Until Now: 0.854
#
# Patience 3
# Epoch: 30/100 | Training Loss: 0.377 | Valid Score: 0.824
#
# Epoch: 30/100 | Best Valid Score Until Now: 0.854
#
# Save checkpoint
# Epoch: 31/100 | Training Loss: 0.372 | Valid Score: 0.855
#
# Epoch: 31/100 | Best Valid Score Until Now: 0.855
#
# Save checkpoint
# Epoch: 32/100 | Training Loss: 0.363 | Valid Score: 0.862
#
# Epoch: 32/100 | Best Valid Score Until Now: 0.862
#
# Patience 1
# Epoch: 33/100 | Training Loss: 0.357 | Valid Score: 0.850
#
# Epoch: 33/100 | Best Valid Score Until Now: 0.862
#
# Patience 2
# Epoch: 34/100 | Training Loss: 0.353 | Valid Score: 0.858
#
# Epoch: 34/100 | Best Valid Score Until Now: 0.862
#
# Save checkpoint
# Epoch: 35/100 | Training Loss: 0.347 | Valid Score: 0.866
#
# Epoch: 35/100 | Best Valid Score Until Now: 0.866
#
# Patience 1
# Epoch: 36/100 | Training Loss: 0.344 | Valid Score: 0.857
#
# Epoch: 36/100 | Best Valid Score Until Now: 0.866
#
# Patience 2
# Epoch: 37/100 | Training Loss: 0.360 | Valid Score: 0.860
#
# Epoch: 37/100 | Best Valid Score Until Now: 0.866
#
# Save checkpoint
# Epoch: 38/100 | Training Loss: 0.353 | Valid Score: 0.869
#
# Epoch: 38/100 | Best Valid Score Until Now: 0.869
#
# Patience 1
# Epoch: 39/100 | Training Loss: 0.345 | Valid Score: 0.863
#
# Epoch: 39/100 | Best Valid Score Until Now: 0.869
#
# Patience 2
# Epoch: 40/100 | Training Loss: 0.344 | Valid Score: 0.866
#
# Epoch: 40/100 | Best Valid Score Until Now: 0.869
#
# Patience 3
# Epoch: 41/100 | Training Loss: 0.337 | Valid Score: 0.854
#
# Epoch: 41/100 | Best Valid Score Until Now: 0.869
#
# Patience 4
# Epoch: 42/100 | Training Loss: 0.329 | Valid Score: 0.866
#
# Epoch: 42/100 | Best Valid Score Until Now: 0.869
#
# Patience 5
# Epoch: 43/100 | Training Loss: 0.328 | Valid Score: 0.855
#
# Epoch: 43/100 | Best Valid Score Until Now: 0.869
#
# Patience 6
# Epoch: 44/100 | Training Loss: 0.325 | Valid Score: 0.860
#
# Epoch: 44/100 | Best Valid Score Until Now: 0.869
#
# Patience 7
# Epoch: 45/100 | Training Loss: 0.329 | Valid Score: 0.852
#
# Epoch: 45/100 | Best Valid Score Until Now: 0.869
#
# Patience 8
# Epoch: 46/100 | Training Loss: 0.316 | Valid Score: 0.858
#
# Epoch: 46/100 | Best Valid Score Until Now: 0.869
#
# Patience 9
# Epoch: 47/100 | Training Loss: 0.328 | Valid Score: 0.868
#
# Epoch: 47/100 | Best Valid Score Until Now: 0.869
#
# Patience 10
# Epoch: 48/100 | Training Loss: 0.346 | Valid Score: 0.858
#
# Epoch: 48/100 | Best Valid Score Until Now: 0.869
#
# Final results:
# Average Valid Score: 0.869
#
# Test Score: 0.787
#
# Execution time: 77.245 seconds

# %% [markdown]
# # GCN 4 Layer

# %%
class GNN(nn.Module):
    def __init__(self, config, global_size=200, num_tasks=1):
        super().__init__()
        self.config = config
        self.num_tasks = num_tasks

        # Node feature size
        self.node_feature_size = self.config.get('node_feature_size', 127)

        # Edge feature size
        self.edge_feature_size = self.config.get('edge_feature_size', 12)

        # Hidden size
        self.hidden_size = self.config.get('hidden_size', 100)

        self.conv1 = GraphConv(self.node_feature_size, self.hidden_size, allow_zero_in_degree=True)
        self.conv2 = GraphConv(self.hidden_size, self.hidden_size, allow_zero_in_degree=True)
        self.conv3 = GraphConv(self.hidden_size, self.hidden_size, allow_zero_in_degree=True)
        self.conv4 = GraphConv(self.hidden_size, self.num_tasks, allow_zero_in_degree=True)

    def forward(self, mol_dgl_graph, globals):
        mol_dgl_graph.ndata["v"] = mol_dgl_graph.ndata["v"][:, :self.node_feature_size]
        mol_dgl_graph.edata["e"] = mol_dgl_graph.edata["e"][:, :self.edge_feature_size]

        h = mol_dgl_graph.ndata["v"]
        h = self.conv1(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.conv2(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.conv3(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.conv4(mol_dgl_graph, h)
        mol_dgl_graph.ndata["h"] = h
        return dgl.mean_nodes(mol_dgl_graph, "h")

# %%
import time
start_time = time.time()

train_evaluate()
test_evaluate()
# Out:
# Save checkpoint
# Epoch: 1/100 | Training Loss: 0.632 | Valid Score: 0.439
#
# Epoch: 1/100 | Best Valid Score Until Now: 0.439
#
# Save checkpoint
# Epoch: 2/100 | Training Loss: 0.597 | Valid Score: 0.445
#
# Epoch: 2/100 | Best Valid Score Until Now: 0.445
#
# Save checkpoint
# Epoch: 3/100 | Training Loss: 0.586 | Valid Score: 0.459
#
# Epoch: 3/100 | Best Valid Score Until Now: 0.459
#
# Save checkpoint
# Epoch: 4/100 | Training Loss: 0.578 | Valid Score: 0.492
#
# Epoch: 4/100 | Best Valid Score Until Now: 0.492
#
# Save checkpoint
# Epoch: 5/100 | Training Loss: 0.568 | Valid Score: 0.561
#
# Epoch: 5/100 | Best Valid Score Until Now: 0.561
#
# Save checkpoint
# Epoch: 6/100 | Training Loss: 0.560 | Valid Score: 0.592
#
# Epoch: 6/100 | Best Valid Score Until Now: 0.592
#
# Save checkpoint
# Epoch: 7/100 | Training Loss: 0.547 | Valid Score: 0.604
#
# Epoch: 7/100 | Best Valid Score Until Now: 0.604
#
# Save checkpoint
# Epoch: 8/100 | Training Loss: 0.537 | Valid Score: 0.622
#
# Epoch: 8/100 | Best Valid Score Until Now: 0.622
#
# Save checkpoint
# Epoch: 9/100 | Training Loss: 0.525 | Valid Score: 0.626
#
# Epoch: 9/100 | Best Valid Score Until Now: 0.626
#
# Patience 1
# Epoch: 10/100 | Training Loss: 0.515 | Valid Score: 0.626
#
# Epoch: 10/100 | Best Valid Score Until Now: 0.626
#
# Save checkpoint
# Epoch: 11/100 | Training Loss: 0.501 | Valid Score: 0.629
#
# Epoch: 11/100 | Best Valid Score Until Now: 0.629
#
# Save checkpoint
# Epoch: 12/100 | Training Loss: 0.488 | Valid Score: 0.630
#
# Epoch: 12/100 | Best Valid Score Until Now: 0.630
#
# Save checkpoint
# Epoch: 13/100 | Training Loss: 0.479 | Valid Score: 0.633
#
# Epoch: 13/100 | Best Valid Score Until Now: 0.633
#
# Save checkpoint
# Epoch: 14/100 | Training Loss: 0.470 | Valid Score: 0.636
#
# Epoch: 14/100 | Best Valid Score Until Now: 0.636
#
# Save checkpoint
# Epoch: 15/100 | Training Loss: 0.459 | Valid Score: 0.642
#
# Epoch: 15/100 | Best Valid Score Until Now: 0.642
#
# Save checkpoint
# Epoch: 16/100 | Training Loss: 0.453 | Valid Score: 0.644
#
# Epoch: 16/100 | Best Valid Score Until Now: 0.644
#
# Save checkpoint
# Epoch: 17/100 | Training Loss: 0.447 | Valid Score: 0.652
#
# Epoch: 17/100 | Best Valid Score Until Now: 0.652
#
# Save checkpoint
# Epoch: 18/100 | Training Loss: 0.446 | Valid Score: 0.657
#
# Epoch: 18/100 | Best Valid Score Until Now: 0.657
#
# Save checkpoint
# Epoch: 19/100 | Training Loss: 0.437 | Valid Score: 0.662
#
# Epoch: 19/100 | Best Valid Score Until Now: 0.662
#
# Save checkpoint
# Epoch: 20/100 | Training Loss: 0.431 | Valid Score: 0.667
#
# Epoch: 20/100 | Best Valid Score Until Now: 0.667
#
# Save checkpoint
# Epoch: 21/100 | Training Loss: 0.431 | Valid Score: 0.673
#
# Epoch: 21/100 | Best Valid Score Until Now: 0.673
#
# Save checkpoint
# Epoch: 22/100 | Training Loss: 0.428 | Valid Score: 0.678
#
# Epoch: 22/100 | Best Valid Score Until Now: 0.678
#
# Save checkpoint
# Epoch: 23/100 | Training Loss: 0.423 | Valid Score: 0.685
#
# Epoch: 23/100 | Best Valid Score Until Now: 0.685
#
# Save checkpoint
# Epoch: 24/100 | Training Loss: 0.420 | Valid Score: 0.688
#
# Epoch: 24/100 | Best Valid Score Until Now: 0.688
#
# Save checkpoint
# Epoch: 25/100 | Training Loss: 0.417 | Valid Score: 0.692
#
# Epoch: 25/100 | Best Valid Score Until Now: 0.692
#
# Save checkpoint
# Epoch: 26/100 | Training Loss: 0.414 | Valid Score: 0.696
#
# Epoch: 26/100 | Best Valid Score Until Now: 0.696
#
# Save checkpoint
# Epoch: 27/100 | Training Loss: 0.413 | Valid Score: 0.701
#
# Epoch: 27/100 | Best Valid Score Until Now: 0.701
#
# Save checkpoint
# Epoch: 28/100 | Training Loss: 0.406 | Valid Score: 0.703
#
# Epoch: 28/100 | Best Valid Score Until Now: 0.703
#
# Save checkpoint
# Epoch: 29/100 | Training Loss: 0.405 | Valid Score: 0.706
#
# Epoch: 29/100 | Best Valid Score Until Now: 0.706
#
# Save checkpoint
# Epoch: 30/100 | Training Loss: 0.405 | Valid Score: 0.712
#
# Epoch: 30/100 | Best Valid Score Until Now: 0.712
#
# Save checkpoint
# Epoch: 31/100 | Training Loss: 0.399 | Valid Score: 0.712
#
# Epoch: 31/100 | Best Valid Score Until Now: 0.712
#
# Save checkpoint
# Epoch: 32/100 | Training Loss: 0.402 | Valid Score: 0.714
#
# Epoch: 32/100 | Best Valid Score Until Now: 0.714
#
# Save checkpoint
# Epoch: 33/100 | Training Loss: 0.398 | Valid Score: 0.719
#
# Epoch: 33/100 | Best Valid Score Until Now: 0.719
#
# Save checkpoint
# Epoch: 34/100 | Training Loss: 0.400 | Valid Score: 0.722
#
# Epoch: 34/100 | Best Valid Score Until Now: 0.722
#
# Save checkpoint
# Epoch: 35/100 | Training Loss: 0.398 | Valid Score: 0.724
#
# Epoch: 35/100 | Best Valid Score Until Now: 0.724
#
# Save checkpoint
# Epoch: 36/100 | Training Loss: 0.397 | Valid Score: 0.731
#
# Epoch: 36/100 | Best Valid Score Until Now: 0.731
#
# Patience 1
# Epoch: 37/100 | Training Loss: 0.393 | Valid Score: 0.728
#
# Epoch: 37/100 | Best Valid Score Until Now: 0.731
#
# Patience 2
# Epoch: 38/100 | Training Loss: 0.392 | Valid Score: 0.726
#
# Epoch: 38/100 | Best Valid Score Until Now: 0.731
#
# Save checkpoint
# Epoch: 39/100 | Training Loss: 0.388 | Valid Score: 0.736
#
# Epoch: 39/100 | Best Valid Score Until Now: 0.736
#
# Save checkpoint
# Epoch: 40/100 | Training Loss: 0.393 | Valid Score: 0.739
#
# Epoch: 40/100 | Best Valid Score Until Now: 0.739
#
# Save checkpoint
# Epoch: 41/100 | Training Loss: 0.392 | Valid Score: 0.740
#
# Epoch: 41/100 | Best Valid Score Until Now: 0.740
#
# Save checkpoint
# Epoch: 42/100 | Training Loss: 0.390 | Valid Score: 0.741
#
# Epoch: 42/100 | Best Valid Score Until Now: 0.741
#
# Save checkpoint
# Epoch: 43/100 | Training Loss: 0.388 | Valid Score: 0.742
#
# Epoch: 43/100 | Best Valid Score Until Now: 0.742
#
# Save checkpoint
# Epoch: 44/100 | Training Loss: 0.387 | Valid Score: 0.744
#
# Epoch: 44/100 | Best Valid Score Until Now: 0.744
#
# Patience 1
# Epoch: 45/100 | Training Loss: 0.385 | Valid Score: 0.743
#
# Epoch: 45/100 | Best Valid Score Until Now: 0.744
#
# Save checkpoint
# Epoch: 46/100 | Training Loss: 0.387 | Valid Score: 0.747
#
# Epoch: 46/100 | Best Valid Score Until Now: 0.747
#
# Patience 1
# Epoch: 47/100 | Training Loss: 0.383 | Valid Score: 0.747
#
# Epoch: 47/100 | Best Valid Score Until Now: 0.747
#
# Save checkpoint
# Epoch: 48/100 | Training Loss: 0.386 | Valid Score: 0.754
#
# Epoch: 48/100 | Best Valid Score Until Now: 0.754
#
# Patience 1
# Epoch: 49/100 | Training Loss: 0.383 | Valid Score: 0.749
#
# Epoch: 49/100 | Best Valid Score Until Now: 0.754
#
# Save checkpoint
# Epoch: 50/100 | Training Loss: 0.381 | Valid Score: 0.756
#
# Epoch: 50/100 | Best Valid Score Until Now: 0.756
#
# Save checkpoint
# Epoch: 51/100 | Training Loss: 0.381 | Valid Score: 0.759
#
# Epoch: 51/100 | Best Valid Score Until Now: 0.759
#
# Save checkpoint
# Epoch: 52/100 | Training Loss: 0.381 | Valid Score: 0.761
#
# Epoch: 52/100 | Best Valid Score Until Now: 0.761
#
# Patience 1
# Epoch: 53/100 | Training Loss: 0.377 | Valid Score: 0.761
#
# Epoch: 53/100 | Best Valid Score Until Now: 0.761
#
# Save checkpoint
# Epoch: 54/100 | Training Loss: 0.378 | Valid Score: 0.764
#
# Epoch: 54/100 | Best Valid Score Until Now: 0.764
#
# Save checkpoint
# Epoch: 55/100 | Training Loss: 0.378 | Valid Score: 0.764
#
# Epoch: 55/100 | Best Valid Score Until Now: 0.764
#
# Save checkpoint
# Epoch: 56/100 | Training Loss: 0.374 | Valid Score: 0.767
#
# Epoch: 56/100 | Best Valid Score Until Now: 0.767
#
# Patience 1
# Epoch: 57/100 | Training Loss: 0.375 | Valid Score: 0.763
#
# Epoch: 57/100 | Best Valid Score Until Now: 0.767
#
# Save checkpoint
# Epoch: 58/100 | Training Loss: 0.375 | Valid Score: 0.770
#
# Epoch: 58/100 | Best Valid Score Until Now: 0.770
#
# Save checkpoint
# Epoch: 59/100 | Training Loss: 0.371 | Valid Score: 0.772
#
# Epoch: 59/100 | Best Valid Score Until Now: 0.772
#
# Patience 1
# Epoch: 60/100 | Training Loss: 0.371 | Valid Score: 0.768
#
# Epoch: 60/100 | Best Valid Score Until Now: 0.772
#
# Save checkpoint
# Epoch: 61/100 | Training Loss: 0.371 | Valid Score: 0.774
#
# Epoch: 61/100 | Best Valid Score Until Now: 0.774
#
# Save checkpoint
# Epoch: 62/100 | Training Loss: 0.373 | Valid Score: 0.777
#
# Epoch: 62/100 | Best Valid Score Until Now: 0.777
#
# Patience 1
# Epoch: 63/100 | Training Loss: 0.371 | Valid Score: 0.777
#
# Epoch: 63/100 | Best Valid Score Until Now: 0.777
#
# Patience 2
# Epoch: 64/100 | Training Loss: 0.370 | Valid Score: 0.774
#
# Epoch: 64/100 | Best Valid Score Until Now: 0.777
#
# Patience 3
# Epoch: 65/100 | Training Loss: 0.368 | Valid Score: 0.777
#
# Epoch: 65/100 | Best Valid Score Until Now: 0.777
#
# Save checkpoint
# Epoch: 66/100 | Training Loss: 0.369 | Valid Score: 0.781
#
# Epoch: 66/100 | Best Valid Score Until Now: 0.781
#
# Patience 1
# Epoch: 67/100 | Training Loss: 0.370 | Valid Score: 0.777
#
# Epoch: 67/100 | Best Valid Score Until Now: 0.781
#
# Save checkpoint
# Epoch: 68/100 | Training Loss: 0.368 | Valid Score: 0.782
#
# Epoch: 68/100 | Best Valid Score Until Now: 0.782
#
# Patience 1
# Epoch: 69/100 | Training Loss: 0.366 | Valid Score: 0.782
#
# Epoch: 69/100 | Best Valid Score Until Now: 0.782
#
# Save checkpoint
# Epoch: 70/100 | Training Loss: 0.366 | Valid Score: 0.785
#
# Epoch: 70/100 | Best Valid Score Until Now: 0.785
#
# Patience 1
# Epoch: 71/100 | Training Loss: 0.364 | Valid Score: 0.781
#
# Epoch: 71/100 | Best Valid Score Until Now: 0.785
#
# Save checkpoint
# Epoch: 72/100 | Training Loss: 0.367 | Valid Score: 0.788
#
# Epoch: 72/100 | Best Valid Score Until Now: 0.788
#
# Patience 1
# Epoch: 73/100 | Training Loss: 0.367 | Valid Score: 0.786
#
# Epoch: 73/100 | Best Valid Score Until Now: 0.788
#
# Save checkpoint
# Epoch: 74/100 | Training Loss: 0.363 | Valid Score: 0.791
#
# Epoch: 74/100 | Best Valid Score Until Now: 0.791
#
# Patience 1
# Epoch: 75/100 | Training Loss: 0.366 | Valid Score: 0.790
#
# Epoch: 75/100 | Best Valid Score Until Now: 0.791
#
# Patience 2
# Epoch: 76/100 | Training Loss: 0.366 | Valid Score: 0.790
#
# Epoch: 76/100 | Best Valid Score Until Now: 0.791
#
# Patience 3
# Epoch: 77/100 | Training Loss: 0.363 | Valid Score: 0.788
#
# Epoch: 77/100 | Best Valid Score Until Now: 0.791
#
# Patience 4
# Epoch: 78/100 | Training Loss: 0.361 | Valid Score: 0.788
#
# Epoch: 78/100 | Best Valid Score Until Now: 0.791
#
# Patience 5
# Epoch: 79/100 | Training Loss: 0.364 | Valid Score: 0.788
#
# Epoch: 79/100 | Best Valid Score Until Now: 0.791
#
# Save checkpoint
# Epoch: 80/100 | Training Loss: 0.359 | Valid Score: 0.792
#
# Epoch: 80/100 | Best Valid Score Until Now: 0.792
#
# Save checkpoint
# Epoch: 81/100 | Training Loss: 0.362 | Valid Score: 0.795
#
# Epoch: 81/100 | Best Valid Score Until Now: 0.795
#
# Save checkpoint
# Epoch: 82/100 | Training Loss: 0.361 | Valid Score: 0.797
#
# Epoch: 82/100 | Best Valid Score Until Now: 0.797
#
# Patience 1
# Epoch: 83/100 | Training Loss: 0.358 | Valid Score: 0.795
#
# Epoch: 83/100 | Best Valid Score Until Now: 0.797
#
# Save checkpoint
# Epoch: 84/100 | Training Loss: 0.357 | Valid Score: 0.797
#
# Epoch: 84/100 | Best Valid Score Until Now: 0.797
#
# Patience 1
# Epoch: 85/100 | Training Loss: 0.355 | Valid Score: 0.794
#
# Epoch: 85/100 | Best Valid Score Until Now: 0.797
#
# Save checkpoint
# Epoch: 86/100 | Training Loss: 0.355 | Valid Score: 0.798
#
# Epoch: 86/100 | Best Valid Score Until Now: 0.798
#
# Save checkpoint
# Epoch: 87/100 | Training Loss: 0.360 | Valid Score: 0.798
#
# Epoch: 87/100 | Best Valid Score Until Now: 0.798
#
# Save checkpoint
# Epoch: 88/100 | Training Loss: 0.355 | Valid Score: 0.802
#
# Epoch: 88/100 | Best Valid Score Until Now: 0.802
#
# Patience 1
# Epoch: 89/100 | Training Loss: 0.357 | Valid Score: 0.799
#
# Epoch: 89/100 | Best Valid Score Until Now: 0.802
#
# Patience 2
# Epoch: 90/100 | Training Loss: 0.352 | Valid Score: 0.799
#
# Epoch: 90/100 | Best Valid Score Until Now: 0.802
#
# Save checkpoint
# Epoch: 91/100 | Training Loss: 0.354 | Valid Score: 0.803
#
# Epoch: 91/100 | Best Valid Score Until Now: 0.803
#
# Patience 1
# Epoch: 92/100 | Training Loss: 0.349 | Valid Score: 0.802
#
# Epoch: 92/100 | Best Valid Score Until Now: 0.803
#
# Patience 2
# Epoch: 93/100 | Training Loss: 0.351 | Valid Score: 0.800
#
# Epoch: 93/100 | Best Valid Score Until Now: 0.803
#
# Patience 3
# Epoch: 94/100 | Training Loss: 0.352 | Valid Score: 0.803
#
# Epoch: 94/100 | Best Valid Score Until Now: 0.803
#
# Save checkpoint
# Epoch: 95/100 | Training Loss: 0.351 | Valid Score: 0.804
#
# Epoch: 95/100 | Best Valid Score Until Now: 0.804
#
# Save checkpoint
# Epoch: 96/100 | Training Loss: 0.351 | Valid Score: 0.808
#
# Epoch: 96/100 | Best Valid Score Until Now: 0.808
#
# Save checkpoint
# Epoch: 97/100 | Training Loss: 0.350 | Valid Score: 0.808
#
# Epoch: 97/100 | Best Valid Score Until Now: 0.808
#
# Patience 1
# Epoch: 98/100 | Training Loss: 0.351 | Valid Score: 0.808
#
# Epoch: 98/100 | Best Valid Score Until Now: 0.808
#
# Save checkpoint
# Epoch: 99/100 | Training Loss: 0.350 | Valid Score: 0.810
#
# Epoch: 99/100 | Best Valid Score Until Now: 0.810
#
# Patience 1
# Epoch: 100/100 | Training Loss: 0.348 | Valid Score: 0.809
#
# Epoch: 100/100 | Best Valid Score Until Now: 0.810
#
# Final results:
# Average Valid Score: 0.810
#
# Test Score: 0.791
#
# Execution time: 80.840 seconds

# %% [markdown]
# # GCN 2Layer

# %%
class GNN(nn.Module):
    def __init__(self, config, global_size = 200, num_tasks = 1):
        super().__init__()
        self.config = config
        self.num_tasks = num_tasks

        # Node feature size
        self.node_feature_size = self.config.get('node_feature_size', 127)

        # Edge feature size
        self.edge_feature_size = self.config.get('edge_feature_size', 12)

        # Hidden size
        self.hidden_size = self.config.get('hidden_size', 100)

        self.conv1 = GraphConv(self.node_feature_size, self.hidden_size, allow_zero_in_degree=True)
        self.conv2 = GraphConv(self.hidden_size, self.num_tasks, allow_zero_in_degree=True)

    # def forward(self, g, in_feat):
    def forward(self, mol_dgl_graph, globals):
        mol_dgl_graph.ndata["v"]= mol_dgl_graph.ndata["v"][:,:self.node_feature_size]
        mol_dgl_graph.edata["e"] = mol_dgl_graph.edata["e"][:,:self.edge_feature_size]
        h = self.conv1(mol_dgl_graph, mol_dgl_graph.ndata["v"])
        h = F.relu(h)
        h = self.conv2(mol_dgl_graph, h)
        mol_dgl_graph.ndata["h"] = h
        return dgl.mean_nodes(mol_dgl_graph, "h")

# %%
import time
start_time = time.time()

train_evaluate()
test_evaluate()
# Out:
# Save checkpoint
# Epoch: 1/100 | Training Loss: 0.606 | Valid Score: 0.438
#
# Epoch: 1/100 | Best Valid Score Until Now: 0.438
#
# Patience 1
# Epoch: 2/100 | Training Loss: 0.597 | Valid Score: 0.433
#
# Epoch: 2/100 | Best Valid Score Until Now: 0.438
#
# Patience 2
# Epoch: 3/100 | Training Loss: 0.591 | Valid Score: 0.436
#
# Epoch: 3/100 | Best Valid Score Until Now: 0.438
#
# Save checkpoint
# Epoch: 4/100 | Training Loss: 0.587 | Valid Score: 0.444
#
# Epoch: 4/100 | Best Valid Score Until Now: 0.444
#
# Save checkpoint
# Epoch: 5/100 | Training Loss: 0.583 | Valid Score: 0.451
#
# Epoch: 5/100 | Best Valid Score Until Now: 0.451
#
# Save checkpoint
# Epoch: 6/100 | Training Loss: 0.580 | Valid Score: 0.460
#
# Epoch: 6/100 | Best Valid Score Until Now: 0.460
#
# Save checkpoint
# Epoch: 7/100 | Training Loss: 0.579 | Valid Score: 0.474
#
# Epoch: 7/100 | Best Valid Score Until Now: 0.474
#
# Save checkpoint
# Epoch: 8/100 | Training Loss: 0.573 | Valid Score: 0.485
#
# Epoch: 8/100 | Best Valid Score Until Now: 0.485
#
# Save checkpoint
# Epoch: 9/100 | Training Loss: 0.570 | Valid Score: 0.499
#
# Epoch: 9/100 | Best Valid Score Until Now: 0.499
#
# Save checkpoint
# Epoch: 10/100 | Training Loss: 0.567 | Valid Score: 0.517
#
# Epoch: 10/100 | Best Valid Score Until Now: 0.517
#
# Save checkpoint
# Epoch: 11/100 | Training Loss: 0.562 | Valid Score: 0.526
#
# Epoch: 11/100 | Best Valid Score Until Now: 0.526
#
# Save checkpoint
# Epoch: 12/100 | Training Loss: 0.562 | Valid Score: 0.541
#
# Epoch: 12/100 | Best Valid Score Until Now: 0.541
#
# Save checkpoint
# Epoch: 13/100 | Training Loss: 0.557 | Valid Score: 0.552
#
# Epoch: 13/100 | Best Valid Score Until Now: 0.552
#
# Save checkpoint
# Epoch: 14/100 | Training Loss: 0.554 | Valid Score: 0.563
#
# Epoch: 14/100 | Best Valid Score Until Now: 0.563
#
# Save checkpoint
# Epoch: 15/100 | Training Loss: 0.551 | Valid Score: 0.567
#
# Epoch: 15/100 | Best Valid Score Until Now: 0.567
#
# Save checkpoint
# Epoch: 16/100 | Training Loss: 0.546 | Valid Score: 0.571
#
# Epoch: 16/100 | Best Valid Score Until Now: 0.571
#
# Save checkpoint
# Epoch: 17/100 | Training Loss: 0.546 | Valid Score: 0.583
#
# Epoch: 17/100 | Best Valid Score Until Now: 0.583
#
# Save checkpoint
# Epoch: 18/100 | Training Loss: 0.542 | Valid Score: 0.584
#
# Epoch: 18/100 | Best Valid Score Until Now: 0.584
#
# Save checkpoint
# Epoch: 19/100 | Training Loss: 0.536 | Valid Score: 0.588
#
# Epoch: 19/100 | Best Valid Score Until Now: 0.588
#
# Save checkpoint
# Epoch: 20/100 | Training Loss: 0.534 | Valid Score: 0.594
#
# Epoch: 20/100 | Best Valid Score Until Now: 0.594
#
# Save checkpoint
# Epoch: 21/100 | Training Loss: 0.531 | Valid Score: 0.600
#
# Epoch: 21/100 | Best Valid Score Until Now: 0.600
#
# Save checkpoint
# Epoch: 22/100 | Training Loss: 0.527 | Valid Score: 0.612
#
# Epoch: 22/100 | Best Valid Score Until Now: 0.612
#
# Save checkpoint
# Epoch: 23/100 | Training Loss: 0.525 | Valid Score: 0.622
#
# Epoch: 23/100 | Best Valid Score Until Now: 0.622
#
# Save checkpoint
# Epoch: 24/100 | Training Loss: 0.521 | Valid Score: 0.627
#
# Epoch: 24/100 | Best Valid Score Until Now: 0.627
#
# Save checkpoint
# Epoch: 25/100 | Training Loss: 0.516 | Valid Score: 0.632
#
# Epoch: 25/100 | Best Valid Score Until Now: 0.632
#
# Save checkpoint
# Epoch: 26/100 | Training Loss: 0.513 | Valid Score: 0.636
#
# Epoch: 26/100 | Best Valid Score Until Now: 0.636
#
# Save checkpoint
# Epoch: 27/100 | Training Loss: 0.508 | Valid Score: 0.642
#
# Epoch: 27/100 | Best Valid Score Until Now: 0.642
#
# Save checkpoint
# Epoch: 28/100 | Training Loss: 0.506 | Valid Score: 0.646
#
# Epoch: 28/100 | Best Valid Score Until Now: 0.646
#
# Save checkpoint
# Epoch: 29/100 | Training Loss: 0.503 | Valid Score: 0.647
#
# Epoch: 29/100 | Best Valid Score Until Now: 0.647
#
# Save checkpoint
# Epoch: 30/100 | Training Loss: 0.501 | Valid Score: 0.650
#
# Epoch: 30/100 | Best Valid Score Until Now: 0.650
#
# Save checkpoint
# Epoch: 31/100 | Training Loss: 0.497 | Valid Score: 0.654
#
# Epoch: 31/100 | Best Valid Score Until Now: 0.654
#
# Save checkpoint
# Epoch: 32/100 | Training Loss: 0.496 | Valid Score: 0.656
#
# Epoch: 32/100 | Best Valid Score Until Now: 0.656
#
# Save checkpoint
# Epoch: 33/100 | Training Loss: 0.496 | Valid Score: 0.661
#
# Epoch: 33/100 | Best Valid Score Until Now: 0.661
#
# Save checkpoint
# Epoch: 34/100 | Training Loss: 0.493 | Valid Score: 0.661
#
# Epoch: 34/100 | Best Valid Score Until Now: 0.661
#
# Save checkpoint
# Epoch: 35/100 | Training Loss: 0.486 | Valid Score: 0.665
#
# Epoch: 35/100 | Best Valid Score Until Now: 0.665
#
# Save checkpoint
# Epoch: 36/100 | Training Loss: 0.486 | Valid Score: 0.667
#
# Epoch: 36/100 | Best Valid Score Until Now: 0.667
#
# Save checkpoint
# Epoch: 37/100 | Training Loss: 0.484 | Valid Score: 0.670
#
# Epoch: 37/100 | Best Valid Score Until Now: 0.670
#
# Save checkpoint
# Epoch: 38/100 | Training Loss: 0.481 | Valid Score: 0.671
#
# Epoch: 38/100 | Best Valid Score Until Now: 0.671
#
# Save checkpoint
# Epoch: 39/100 | Training Loss: 0.481 | Valid Score: 0.673
#
# Epoch: 39/100 | Best Valid Score Until Now: 0.673
#
# Save checkpoint
# Epoch: 40/100 | Training Loss: 0.477 | Valid Score: 0.675
#
# Epoch: 40/100 | Best Valid Score Until Now: 0.675
#
# Patience 1
# Epoch: 41/100 | Training Loss: 0.475 | Valid Score: 0.675
#
# Epoch: 41/100 | Best Valid Score Until Now: 0.675
#
# Save checkpoint
# Epoch: 42/100 | Training Loss: 0.475 | Valid Score: 0.676
#
# Epoch: 42/100 | Best Valid Score Until Now: 0.676
#
# Save checkpoint
# Epoch: 43/100 | Training Loss: 0.473 | Valid Score: 0.679
#
# Epoch: 43/100 | Best Valid Score Until Now: 0.679
#
# Patience 1
# Epoch: 44/100 | Training Loss: 0.471 | Valid Score: 0.678
#
# Epoch: 44/100 | Best Valid Score Until Now: 0.679
#
# Save checkpoint
# Epoch: 45/100 | Training Loss: 0.470 | Valid Score: 0.682
#
# Epoch: 45/100 | Best Valid Score Until Now: 0.682
#
# Save checkpoint
# Epoch: 46/100 | Training Loss: 0.468 | Valid Score: 0.682
#
# Epoch: 46/100 | Best Valid Score Until Now: 0.682
#
# Save checkpoint
# Epoch: 47/100 | Training Loss: 0.466 | Valid Score: 0.682
#
# Epoch: 47/100 | Best Valid Score Until Now: 0.682
#
# Save checkpoint
# Epoch: 48/100 | Training Loss: 0.464 | Valid Score: 0.683
#
# Epoch: 48/100 | Best Valid Score Until Now: 0.683
#
# Save checkpoint
# Epoch: 49/100 | Training Loss: 0.461 | Valid Score: 0.685
#
# Epoch: 49/100 | Best Valid Score Until Now: 0.685
#
# Save checkpoint
# Epoch: 50/100 | Training Loss: 0.461 | Valid Score: 0.686
#
# Epoch: 50/100 | Best Valid Score Until Now: 0.686
#
# Save checkpoint
# Epoch: 51/100 | Training Loss: 0.461 | Valid Score: 0.687
#
# Epoch: 51/100 | Best Valid Score Until Now: 0.687
#
# Save checkpoint
# Epoch: 52/100 | Training Loss: 0.457 | Valid Score: 0.689
#
# Epoch: 52/100 | Best Valid Score Until Now: 0.689
#
# Save checkpoint
# Epoch: 53/100 | Training Loss: 0.458 | Valid Score: 0.690
#
# Epoch: 53/100 | Best Valid Score Until Now: 0.690
#
# Save checkpoint
# Epoch: 54/100 | Training Loss: 0.456 | Valid Score: 0.691
#
# Epoch: 54/100 | Best Valid Score Until Now: 0.691
#
# Save checkpoint
# Epoch: 55/100 | Training Loss: 0.452 | Valid Score: 0.692
#
# Epoch: 55/100 | Best Valid Score Until Now: 0.692
#
# Save checkpoint
# Epoch: 56/100 | Training Loss: 0.455 | Valid Score: 0.692
#
# Epoch: 56/100 | Best Valid Score Until Now: 0.692
#
# Save checkpoint
# Epoch: 57/100 | Training Loss: 0.447 | Valid Score: 0.693
#
# Epoch: 57/100 | Best Valid Score Until Now: 0.693
#
# Save checkpoint
# Epoch: 58/100 | Training Loss: 0.449 | Valid Score: 0.693
#
# Epoch: 58/100 | Best Valid Score Until Now: 0.693
#
# Save checkpoint
# Epoch: 59/100 | Training Loss: 0.449 | Valid Score: 0.694
#
# Epoch: 59/100 | Best Valid Score Until Now: 0.694
#
# Save checkpoint
# Epoch: 60/100 | Training Loss: 0.449 | Valid Score: 0.695
#
# Epoch: 60/100 | Best Valid Score Until Now: 0.695
#
# Save checkpoint
# Epoch: 61/100 | Training Loss: 0.447 | Valid Score: 0.697
#
# Epoch: 61/100 | Best Valid Score Until Now: 0.697
#
# Save checkpoint
# Epoch: 62/100 | Training Loss: 0.445 | Valid Score: 0.698
#
# Epoch: 62/100 | Best Valid Score Until Now: 0.698
#
# Patience 1
# Epoch: 63/100 | Training Loss: 0.443 | Valid Score: 0.698
#
# Epoch: 63/100 | Best Valid Score Until Now: 0.698
#
# Save checkpoint
# Epoch: 64/100 | Training Loss: 0.445 | Valid Score: 0.699
#
# Epoch: 64/100 | Best Valid Score Until Now: 0.699
#
# Save checkpoint
# Epoch: 65/100 | Training Loss: 0.444 | Valid Score: 0.700
#
# Epoch: 65/100 | Best Valid Score Until Now: 0.700
#
# Patience 1
# Epoch: 66/100 | Training Loss: 0.442 | Valid Score: 0.700
#
# Epoch: 66/100 | Best Valid Score Until Now: 0.700
#
# Save checkpoint
# Epoch: 67/100 | Training Loss: 0.438 | Valid Score: 0.701
#
# Epoch: 67/100 | Best Valid Score Until Now: 0.701
#
# Patience 1
# Epoch: 68/100 | Training Loss: 0.440 | Valid Score: 0.701
#
# Epoch: 68/100 | Best Valid Score Until Now: 0.701
#
# Save checkpoint
# Epoch: 69/100 | Training Loss: 0.436 | Valid Score: 0.702
#
# Epoch: 69/100 | Best Valid Score Until Now: 0.702
#
# Save checkpoint
# Epoch: 70/100 | Training Loss: 0.437 | Valid Score: 0.703
#
# Epoch: 70/100 | Best Valid Score Until Now: 0.703
#
# Save checkpoint
# Epoch: 71/100 | Training Loss: 0.438 | Valid Score: 0.704
#
# Epoch: 71/100 | Best Valid Score Until Now: 0.704
#
# Patience 1
# Epoch: 72/100 | Training Loss: 0.439 | Valid Score: 0.704
#
# Epoch: 72/100 | Best Valid Score Until Now: 0.704
#
# Save checkpoint
# Epoch: 73/100 | Training Loss: 0.435 | Valid Score: 0.705
#
# Epoch: 73/100 | Best Valid Score Until Now: 0.705
#
# Save checkpoint
# Epoch: 74/100 | Training Loss: 0.434 | Valid Score: 0.706
#
# Epoch: 74/100 | Best Valid Score Until Now: 0.706
#
# Save checkpoint
# Epoch: 75/100 | Training Loss: 0.434 | Valid Score: 0.708
#
# Epoch: 75/100 | Best Valid Score Until Now: 0.708
#
# Save checkpoint
# Epoch: 76/100 | Training Loss: 0.434 | Valid Score: 0.708
#
# Epoch: 76/100 | Best Valid Score Until Now: 0.708
#
# Save checkpoint
# Epoch: 77/100 | Training Loss: 0.434 | Valid Score: 0.710
#
# Epoch: 77/100 | Best Valid Score Until Now: 0.710
#
# Patience 1
# Epoch: 78/100 | Training Loss: 0.433 | Valid Score: 0.710
#
# Epoch: 78/100 | Best Valid Score Until Now: 0.710
#
# Patience 2
# Epoch: 79/100 | Training Loss: 0.432 | Valid Score: 0.709
#
# Epoch: 79/100 | Best Valid Score Until Now: 0.710
#
# Save checkpoint
# Epoch: 80/100 | Training Loss: 0.428 | Valid Score: 0.711
#
# Epoch: 80/100 | Best Valid Score Until Now: 0.711
#
# Save checkpoint
# Epoch: 81/100 | Training Loss: 0.433 | Valid Score: 0.711
#
# Epoch: 81/100 | Best Valid Score Until Now: 0.711
#
# Patience 1
# Epoch: 82/100 | Training Loss: 0.433 | Valid Score: 0.711
#
# Epoch: 82/100 | Best Valid Score Until Now: 0.711
#
# Patience 2
# Epoch: 83/100 | Training Loss: 0.431 | Valid Score: 0.711
#
# Epoch: 83/100 | Best Valid Score Until Now: 0.711
#
# Save checkpoint
# Epoch: 84/100 | Training Loss: 0.428 | Valid Score: 0.712
#
# Epoch: 84/100 | Best Valid Score Until Now: 0.712
#
# Save checkpoint
# Epoch: 85/100 | Training Loss: 0.430 | Valid Score: 0.712
#
# Epoch: 85/100 | Best Valid Score Until Now: 0.712
#
# Save checkpoint
# Epoch: 86/100 | Training Loss: 0.428 | Valid Score: 0.714
#
# Epoch: 86/100 | Best Valid Score Until Now: 0.714
#
# Save checkpoint
# Epoch: 87/100 | Training Loss: 0.426 | Valid Score: 0.714
#
# Epoch: 87/100 | Best Valid Score Until Now: 0.714
#
# Save checkpoint
# Epoch: 88/100 | Training Loss: 0.425 | Valid Score: 0.714
#
# Epoch: 88/100 | Best Valid Score Until Now: 0.714
#
# Save checkpoint
# Epoch: 89/100 | Training Loss: 0.424 | Valid Score: 0.715
#
# Epoch: 89/100 | Best Valid Score Until Now: 0.715
#
# Save checkpoint
# Epoch: 90/100 | Training Loss: 0.424 | Valid Score: 0.716
#
# Epoch: 90/100 | Best Valid Score Until Now: 0.716
#
# Save checkpoint
# Epoch: 91/100 | Training Loss: 0.428 | Valid Score: 0.717
#
# Epoch: 91/100 | Best Valid Score Until Now: 0.717
#
# Save checkpoint
# Epoch: 92/100 | Training Loss: 0.423 | Valid Score: 0.717
#
# Epoch: 92/100 | Best Valid Score Until Now: 0.717
#
# Save checkpoint
# Epoch: 93/100 | Training Loss: 0.425 | Valid Score: 0.718
#
# Epoch: 93/100 | Best Valid Score Until Now: 0.718
#
# Patience 1
# Epoch: 94/100 | Training Loss: 0.423 | Valid Score: 0.717
#
# Epoch: 94/100 | Best Valid Score Until Now: 0.718
#
# Save checkpoint
# Epoch: 95/100 | Training Loss: 0.422 | Valid Score: 0.719
#
# Epoch: 95/100 | Best Valid Score Until Now: 0.719
#
# Save checkpoint
# Epoch: 96/100 | Training Loss: 0.420 | Valid Score: 0.720
#
# Epoch: 96/100 | Best Valid Score Until Now: 0.720
#
# Save checkpoint
# Epoch: 97/100 | Training Loss: 0.424 | Valid Score: 0.720
#
# Epoch: 97/100 | Best Valid Score Until Now: 0.720
#
# Save checkpoint
# Epoch: 98/100 | Training Loss: 0.423 | Valid Score: 0.721
#
# Epoch: 98/100 | Best Valid Score Until Now: 0.721
#
# Patience 1
# Epoch: 99/100 | Training Loss: 0.419 | Valid Score: 0.721
#
# Epoch: 99/100 | Best Valid Score Until Now: 0.721
#
# Save checkpoint
# Epoch: 100/100 | Training Loss: 0.420 | Valid Score: 0.723
#
# Epoch: 100/100 | Best Valid Score Until Now: 0.723
#
# Final results:
# Average Valid Score: 0.723
#
# Test Score: 0.774
#
# Execution time: 64.990 seconds

# %% [markdown]
# # GraphSage 3Layer

# %%
from dgl.nn import SAGEConv

# %%
class GNN(nn.Module):
    def __init__(self, config, global_size=200, num_tasks=1):
        super().__init__()
        self.config = config
        self.num_tasks = num_tasks

        # Node feature size
        self.node_feature_size = self.config.get('node_feature_size', 127)

        # Edge feature size
        self.edge_feature_size = self.config.get('edge_feature_size', 12)

        # Hidden size
        self.hidden_size = self.config.get('hidden_size', 100)

        self.conv1 = SAGEConv(self.node_feature_size, self.hidden_size,aggregator_type='mean')
        self.conv2 = SAGEConv(self.hidden_size, self.hidden_size,aggregator_type='mean')
        self.conv3 = SAGEConv(self.hidden_size, self.num_tasks,aggregator_type='mean')

    def forward(self, mol_dgl_graph, globals):
        mol_dgl_graph.ndata["v"] = mol_dgl_graph.ndata["v"][:, :self.node_feature_size]
        mol_dgl_graph.edata["e"] = mol_dgl_graph.edata["e"][:, :self.edge_feature_size]

        h = self.conv1(mol_dgl_graph, mol_dgl_graph.ndata["v"])
        h = F.relu(h)
        h = self.conv2(mol_dgl_graph, h)
        h = F.relu(h)
        h = self.conv3(mol_dgl_graph, h)
        mol_dgl_graph.ndata["h"] = h

        return dgl.mean_nodes(mol_dgl_graph, "h")

# %%
import time
start_time = time.time()

train_evaluate()
test_evaluate()
# Out:
# Save checkpoint
# Epoch: 1/100 | Training Loss: 1.320 | Valid Score: 0.372
#
# Epoch: 1/100 | Best Valid Score Until Now: 0.372
#
# Patience 1
# Epoch: 2/100 | Training Loss: 0.626 | Valid Score: 0.284
#
# Epoch: 2/100 | Best Valid Score Until Now: 0.372
#
# Patience 2
# Epoch: 3/100 | Training Loss: 0.597 | Valid Score: 0.323
#
# Epoch: 3/100 | Best Valid Score Until Now: 0.372
#
# Save checkpoint
# Epoch: 4/100 | Training Loss: 0.572 | Valid Score: 0.396
#
# Epoch: 4/100 | Best Valid Score Until Now: 0.396
#
# Save checkpoint
# Epoch: 5/100 | Training Loss: 0.548 | Valid Score: 0.460
#
# Epoch: 5/100 | Best Valid Score Until Now: 0.460
#
# Save checkpoint
# Epoch: 6/100 | Training Loss: 0.530 | Valid Score: 0.505
#
# Epoch: 6/100 | Best Valid Score Until Now: 0.505
#
# Save checkpoint
# Epoch: 7/100 | Training Loss: 0.513 | Valid Score: 0.558
#
# Epoch: 7/100 | Best Valid Score Until Now: 0.558
#
# Save checkpoint
# Epoch: 8/100 | Training Loss: 0.503 | Valid Score: 0.598
#
# Epoch: 8/100 | Best Valid Score Until Now: 0.598
#
# Save checkpoint
# Epoch: 9/100 | Training Loss: 0.489 | Valid Score: 0.617
#
# Epoch: 9/100 | Best Valid Score Until Now: 0.617
#
# Save checkpoint
# Epoch: 10/100 | Training Loss: 0.475 | Valid Score: 0.631
#
# Epoch: 10/100 | Best Valid Score Until Now: 0.631
#
# Save checkpoint
# Epoch: 11/100 | Training Loss: 0.466 | Valid Score: 0.641
#
# Epoch: 11/100 | Best Valid Score Until Now: 0.641
#
# Save checkpoint
# Epoch: 12/100 | Training Loss: 0.454 | Valid Score: 0.665
#
# Epoch: 12/100 | Best Valid Score Until Now: 0.665
#
# Save checkpoint
# Epoch: 13/100 | Training Loss: 0.443 | Valid Score: 0.681
#
# Epoch: 13/100 | Best Valid Score Until Now: 0.681
#
# Save checkpoint
# Epoch: 14/100 | Training Loss: 0.437 | Valid Score: 0.700
#
# Epoch: 14/100 | Best Valid Score Until Now: 0.700
#
# Save checkpoint
# Epoch: 15/100 | Training Loss: 0.427 | Valid Score: 0.716
#
# Epoch: 15/100 | Best Valid Score Until Now: 0.716
#
# Save checkpoint
# Epoch: 16/100 | Training Loss: 0.422 | Valid Score: 0.726
#
# Epoch: 16/100 | Best Valid Score Until Now: 0.726
#
# Save checkpoint
# Epoch: 17/100 | Training Loss: 0.418 | Valid Score: 0.731
#
# Epoch: 17/100 | Best Valid Score Until Now: 0.731
#
# Save checkpoint
# Epoch: 18/100 | Training Loss: 0.416 | Valid Score: 0.737
#
# Epoch: 18/100 | Best Valid Score Until Now: 0.737
#
# Save checkpoint
# Epoch: 19/100 | Training Loss: 0.408 | Valid Score: 0.742
#
# Epoch: 19/100 | Best Valid Score Until Now: 0.742
#
# Save checkpoint
# Epoch: 20/100 | Training Loss: 0.405 | Valid Score: 0.745
#
# Epoch: 20/100 | Best Valid Score Until Now: 0.745
#
# Save checkpoint
# Epoch: 21/100 | Training Loss: 0.401 | Valid Score: 0.750
#
# Epoch: 21/100 | Best Valid Score Until Now: 0.750
#
# Save checkpoint
# Epoch: 22/100 | Training Loss: 0.398 | Valid Score: 0.756
#
# Epoch: 22/100 | Best Valid Score Until Now: 0.756
#
# Patience 1
# Epoch: 23/100 | Training Loss: 0.399 | Valid Score: 0.755
#
# Epoch: 23/100 | Best Valid Score Until Now: 0.756
#
# Save checkpoint
# Epoch: 24/100 | Training Loss: 0.394 | Valid Score: 0.761
#
# Epoch: 24/100 | Best Valid Score Until Now: 0.761
#
# Save checkpoint
# Epoch: 25/100 | Training Loss: 0.390 | Valid Score: 0.765
#
# Epoch: 25/100 | Best Valid Score Until Now: 0.765
#
# Save checkpoint
# Epoch: 26/100 | Training Loss: 0.390 | Valid Score: 0.768
#
# Epoch: 26/100 | Best Valid Score Until Now: 0.768
#
# Save checkpoint
# Epoch: 27/100 | Training Loss: 0.385 | Valid Score: 0.770
#
# Epoch: 27/100 | Best Valid Score Until Now: 0.770
#
# Save checkpoint
# Epoch: 28/100 | Training Loss: 0.385 | Valid Score: 0.773
#
# Epoch: 28/100 | Best Valid Score Until Now: 0.773
#
# Patience 1
# Epoch: 29/100 | Training Loss: 0.383 | Valid Score: 0.771
#
# Epoch: 29/100 | Best Valid Score Until Now: 0.773
#
# Save checkpoint
# Epoch: 30/100 | Training Loss: 0.376 | Valid Score: 0.779
#
# Epoch: 30/100 | Best Valid Score Until Now: 0.779
#
# Patience 1
# Epoch: 31/100 | Training Loss: 0.378 | Valid Score: 0.778
#
# Epoch: 31/100 | Best Valid Score Until Now: 0.779
#
# Save checkpoint
# Epoch: 32/100 | Training Loss: 0.378 | Valid Score: 0.786
#
# Epoch: 32/100 | Best Valid Score Until Now: 0.786
#
# Patience 1
# Epoch: 33/100 | Training Loss: 0.375 | Valid Score: 0.774
#
# Epoch: 33/100 | Best Valid Score Until Now: 0.786
#
# Save checkpoint
# Epoch: 34/100 | Training Loss: 0.371 | Valid Score: 0.786
#
# Epoch: 34/100 | Best Valid Score Until Now: 0.786
#
# Save checkpoint
# Epoch: 35/100 | Training Loss: 0.374 | Valid Score: 0.792
#
# Epoch: 35/100 | Best Valid Score Until Now: 0.792
#
# Save checkpoint
# Epoch: 36/100 | Training Loss: 0.376 | Valid Score: 0.795
#
# Epoch: 36/100 | Best Valid Score Until Now: 0.795
#
# Save checkpoint
# Epoch: 37/100 | Training Loss: 0.371 | Valid Score: 0.798
#
# Epoch: 37/100 | Best Valid Score Until Now: 0.798
#
# Patience 1
# Epoch: 38/100 | Training Loss: 0.370 | Valid Score: 0.795
#
# Epoch: 38/100 | Best Valid Score Until Now: 0.798
#
# Save checkpoint
# Epoch: 39/100 | Training Loss: 0.368 | Valid Score: 0.803
#
# Epoch: 39/100 | Best Valid Score Until Now: 0.803
#
# Patience 1
# Epoch: 40/100 | Training Loss: 0.371 | Valid Score: 0.798
#
# Epoch: 40/100 | Best Valid Score Until Now: 0.803
#
# Patience 2
# Epoch: 41/100 | Training Loss: 0.362 | Valid Score: 0.803
#
# Epoch: 41/100 | Best Valid Score Until Now: 0.803
#
# Save checkpoint
# Epoch: 42/100 | Training Loss: 0.364 | Valid Score: 0.804
#
# Epoch: 42/100 | Best Valid Score Until Now: 0.804
#
# Patience 1
# Epoch: 43/100 | Training Loss: 0.364 | Valid Score: 0.804
#
# Epoch: 43/100 | Best Valid Score Until Now: 0.804
#
# Save checkpoint
# Epoch: 44/100 | Training Loss: 0.363 | Valid Score: 0.809
#
# Epoch: 44/100 | Best Valid Score Until Now: 0.809
#
# Patience 1
# Epoch: 45/100 | Training Loss: 0.358 | Valid Score: 0.808
#
# Epoch: 45/100 | Best Valid Score Until Now: 0.809
#
# Save checkpoint
# Epoch: 46/100 | Training Loss: 0.359 | Valid Score: 0.816
#
# Epoch: 46/100 | Best Valid Score Until Now: 0.816
#
# Save checkpoint
# Epoch: 47/100 | Training Loss: 0.354 | Valid Score: 0.818
#
# Epoch: 47/100 | Best Valid Score Until Now: 0.818
#
# Save checkpoint
# Epoch: 48/100 | Training Loss: 0.358 | Valid Score: 0.821
#
# Epoch: 48/100 | Best Valid Score Until Now: 0.821
#
# Patience 1
# Epoch: 49/100 | Training Loss: 0.354 | Valid Score: 0.817
#
# Epoch: 49/100 | Best Valid Score Until Now: 0.821
#
# Save checkpoint
# Epoch: 50/100 | Training Loss: 0.354 | Valid Score: 0.826
#
# Epoch: 50/100 | Best Valid Score Until Now: 0.826
#
# Patience 1
# Epoch: 51/100 | Training Loss: 0.356 | Valid Score: 0.815
#
# Epoch: 51/100 | Best Valid Score Until Now: 0.826
#
# Save checkpoint
# Epoch: 52/100 | Training Loss: 0.354 | Valid Score: 0.826
#
# Epoch: 52/100 | Best Valid Score Until Now: 0.826
#
# Save checkpoint
# Epoch: 53/100 | Training Loss: 0.353 | Valid Score: 0.830
#
# Epoch: 53/100 | Best Valid Score Until Now: 0.830
#
# Save checkpoint
# Epoch: 54/100 | Training Loss: 0.354 | Valid Score: 0.836
#
# Epoch: 54/100 | Best Valid Score Until Now: 0.836
#
# Save checkpoint
# Epoch: 55/100 | Training Loss: 0.351 | Valid Score: 0.840
#
# Epoch: 55/100 | Best Valid Score Until Now: 0.840
#
# Patience 1
# Epoch: 56/100 | Training Loss: 0.348 | Valid Score: 0.838
#
# Epoch: 56/100 | Best Valid Score Until Now: 0.840
#
# Patience 2
# Epoch: 57/100 | Training Loss: 0.344 | Valid Score: 0.839
#
# Epoch: 57/100 | Best Valid Score Until Now: 0.840
#
# Save checkpoint
# Epoch: 58/100 | Training Loss: 0.347 | Valid Score: 0.842
#
# Epoch: 58/100 | Best Valid Score Until Now: 0.842
#
# Save checkpoint
# Epoch: 59/100 | Training Loss: 0.345 | Valid Score: 0.843
#
# Epoch: 59/100 | Best Valid Score Until Now: 0.843
#
# Save checkpoint
# Epoch: 60/100 | Training Loss: 0.348 | Valid Score: 0.845
#
# Epoch: 60/100 | Best Valid Score Until Now: 0.845
#
# Save checkpoint
# Epoch: 61/100 | Training Loss: 0.345 | Valid Score: 0.846
#
# Epoch: 61/100 | Best Valid Score Until Now: 0.846
#
# Save checkpoint
# Epoch: 62/100 | Training Loss: 0.343 | Valid Score: 0.847
#
# Epoch: 62/100 | Best Valid Score Until Now: 0.847
#
# Patience 1
# Epoch: 63/100 | Training Loss: 0.345 | Valid Score: 0.843
#
# Epoch: 63/100 | Best Valid Score Until Now: 0.847
#
# Save checkpoint
# Epoch: 64/100 | Training Loss: 0.344 | Valid Score: 0.848
#
# Epoch: 64/100 | Best Valid Score Until Now: 0.848
#
# Save checkpoint
# Epoch: 65/100 | Training Loss: 0.346 | Valid Score: 0.857
#
# Epoch: 65/100 | Best Valid Score Until Now: 0.857
#
# Patience 1
# Epoch: 66/100 | Training Loss: 0.343 | Valid Score: 0.855
#
# Epoch: 66/100 | Best Valid Score Until Now: 0.857
#
# Save checkpoint
# Epoch: 67/100 | Training Loss: 0.339 | Valid Score: 0.858
#
# Epoch: 67/100 | Best Valid Score Until Now: 0.858
#
# Patience 1
# Epoch: 68/100 | Training Loss: 0.341 | Valid Score: 0.858
#
# Epoch: 68/100 | Best Valid Score Until Now: 0.858
#
# Patience 2
# Epoch: 69/100 | Training Loss: 0.339 | Valid Score: 0.853
#
# Epoch: 69/100 | Best Valid Score Until Now: 0.858
#
# Patience 3
# Epoch: 70/100 | Training Loss: 0.338 | Valid Score: 0.858
#
# Epoch: 70/100 | Best Valid Score Until Now: 0.858
#
# Save checkpoint
# Epoch: 71/100 | Training Loss: 0.339 | Valid Score: 0.863
#
# Epoch: 71/100 | Best Valid Score Until Now: 0.863
#
# Patience 1
# Epoch: 72/100 | Training Loss: 0.339 | Valid Score: 0.858
#
# Epoch: 72/100 | Best Valid Score Until Now: 0.863
#
# Patience 2
# Epoch: 73/100 | Training Loss: 0.337 | Valid Score: 0.855
#
# Epoch: 73/100 | Best Valid Score Until Now: 0.863
#
# Patience 3
# Epoch: 74/100 | Training Loss: 0.341 | Valid Score: 0.854
#
# Epoch: 74/100 | Best Valid Score Until Now: 0.863
#
# Save checkpoint
# Epoch: 75/100 | Training Loss: 0.336 | Valid Score: 0.867
#
# Epoch: 75/100 | Best Valid Score Until Now: 0.867
#
# Save checkpoint
# Epoch: 76/100 | Training Loss: 0.333 | Valid Score: 0.868
#
# Epoch: 76/100 | Best Valid Score Until Now: 0.868
#
# Save checkpoint
# Epoch: 77/100 | Training Loss: 0.332 | Valid Score: 0.872
#
# Epoch: 77/100 | Best Valid Score Until Now: 0.872
#
# Patience 1
# Epoch: 78/100 | Training Loss: 0.331 | Valid Score: 0.865
#
# Epoch: 78/100 | Best Valid Score Until Now: 0.872
#
# Patience 2
# Epoch: 79/100 | Training Loss: 0.334 | Valid Score: 0.871
#
# Epoch: 79/100 | Best Valid Score Until Now: 0.872
#
# Patience 3
# Epoch: 80/100 | Training Loss: 0.339 | Valid Score: 0.872
#
# Epoch: 80/100 | Best Valid Score Until Now: 0.872
#
# Patience 4
# Epoch: 81/100 | Training Loss: 0.334 | Valid Score: 0.870
#
# Epoch: 81/100 | Best Valid Score Until Now: 0.872
#
# Patience 5
# Epoch: 82/100 | Training Loss: 0.332 | Valid Score: 0.872
#
# Epoch: 82/100 | Best Valid Score Until Now: 0.872
#
# Patience 6
# Epoch: 83/100 | Training Loss: 0.331 | Valid Score: 0.872
#
# Epoch: 83/100 | Best Valid Score Until Now: 0.872
#
# Save checkpoint
# Epoch: 84/100 | Training Loss: 0.332 | Valid Score: 0.876
#
# Epoch: 84/100 | Best Valid Score Until Now: 0.876
#
# Patience 1
# Epoch: 85/100 | Training Loss: 0.332 | Valid Score: 0.876
#
# Epoch: 85/100 | Best Valid Score Until Now: 0.876
#
# Save checkpoint
# Epoch: 86/100 | Training Loss: 0.325 | Valid Score: 0.877
#
# Epoch: 86/100 | Best Valid Score Until Now: 0.877
#
# Save checkpoint
# Epoch: 87/100 | Training Loss: 0.326 | Valid Score: 0.878
#
# Epoch: 87/100 | Best Valid Score Until Now: 0.878
#
# Save checkpoint
# Epoch: 88/100 | Training Loss: 0.328 | Valid Score: 0.879
#
# Epoch: 88/100 | Best Valid Score Until Now: 0.879
#
# Patience 1
# Epoch: 89/100 | Training Loss: 0.326 | Valid Score: 0.875
#
# Epoch: 89/100 | Best Valid Score Until Now: 0.879
#
# Patience 2
# Epoch: 90/100 | Training Loss: 0.325 | Valid Score: 0.877
#
# Epoch: 90/100 | Best Valid Score Until Now: 0.879
#
# Save checkpoint
# Epoch: 91/100 | Training Loss: 0.328 | Valid Score: 0.880
#
# Epoch: 91/100 | Best Valid Score Until Now: 0.880
#
# Save checkpoint
# Epoch: 92/100 | Training Loss: 0.321 | Valid Score: 0.881
#
# Epoch: 92/100 | Best Valid Score Until Now: 0.881
#
# Patience 1
# Epoch: 93/100 | Training Loss: 0.319 | Valid Score: 0.878
#
# Epoch: 93/100 | Best Valid Score Until Now: 0.881
#
# Patience 2
# Epoch: 94/100 | Training Loss: 0.327 | Valid Score: 0.878
#
# Epoch: 94/100 | Best Valid Score Until Now: 0.881
#
# Save checkpoint
# Epoch: 95/100 | Training Loss: 0.325 | Valid Score: 0.882
#
# Epoch: 95/100 | Best Valid Score Until Now: 0.882
#
# Patience 1
# Epoch: 96/100 | Training Loss: 0.325 | Valid Score: 0.879
#
# Epoch: 96/100 | Best Valid Score Until Now: 0.882
#
# Patience 2
# Epoch: 97/100 | Training Loss: 0.320 | Valid Score: 0.881
#
# Epoch: 97/100 | Best Valid Score Until Now: 0.882
#
# Patience 3
# Epoch: 98/100 | Training Loss: 0.325 | Valid Score: 0.879
#
# Epoch: 98/100 | Best Valid Score Until Now: 0.882
#
# Save checkpoint
# Epoch: 99/100 | Training Loss: 0.323 | Valid Score: 0.886
#
# Epoch: 99/100 | Best Valid Score Until Now: 0.886
#
# Patience 1
# Epoch: 100/100 | Training Loss: 0.321 | Valid Score: 0.884
#
# Epoch: 100/100 | Best Valid Score Until Now: 0.886
#
# Final results:
# Average Valid Score: 0.886
#
# Test Score: 0.788
#
# Execution time: 76.006 seconds

# %% [markdown]
# # GraphSage 2 Layer

# %%
class GNN(nn.Module):
    def __init__(self, config, global_size = 200, num_tasks = 1):
        super().__init__()
        self.config = config
        self.num_tasks = num_tasks

        # Node feature size
        self.node_feature_size = self.config.get('node_feature_size', 127)

        # Edge feature size
        self.edge_feature_size = self.config.get('edge_feature_size', 12)

        # Hidden size
        self.hidden_size = self.config.get('hidden_size', 100)

        self.conv1 = SAGEConv(self.node_feature_size, self.hidden_size,aggregator_type='mean')
        self.conv2 = SAGEConv(self.hidden_size, self.num_tasks,aggregator_type='mean')

    # def forward(self, g, in_feat):
    def forward(self, mol_dgl_graph, globals):
        mol_dgl_graph.ndata["v"]= mol_dgl_graph.ndata["v"][:,:self.node_feature_size]
        mol_dgl_graph.edata["e"] = mol_dgl_graph.edata["e"][:,:self.edge_feature_size]
        h = self.conv1(mol_dgl_graph, mol_dgl_graph.ndata["v"])
        h = F.relu(h)
        h = self.conv2(mol_dgl_graph, h)
        mol_dgl_graph.ndata["h"] = h
        return dgl.mean_nodes(mol_dgl_graph, "h")

# %%
import time
start_time = time.time()

train_evaluate()
test_evaluate()
# Out:
# Save checkpoint
# Epoch: 1/100 | Training Loss: 0.658 | Valid Score: 0.423
#
# Epoch: 1/100 | Best Valid Score Until Now: 0.423
#
# Save checkpoint
# Epoch: 2/100 | Training Loss: 0.617 | Valid Score: 0.437
#
# Epoch: 2/100 | Best Valid Score Until Now: 0.437
#
# Save checkpoint
# Epoch: 3/100 | Training Loss: 0.595 | Valid Score: 0.460
#
# Epoch: 3/100 | Best Valid Score Until Now: 0.460
#
# Save checkpoint
# Epoch: 4/100 | Training Loss: 0.576 | Valid Score: 0.493
#
# Epoch: 4/100 | Best Valid Score Until Now: 0.493
#
# Save checkpoint
# Epoch: 5/100 | Training Loss: 0.560 | Valid Score: 0.534
#
# Epoch: 5/100 | Best Valid Score Until Now: 0.534
#
# Save checkpoint
# Epoch: 6/100 | Training Loss: 0.548 | Valid Score: 0.579
#
# Epoch: 6/100 | Best Valid Score Until Now: 0.579
#
# Save checkpoint
# Epoch: 7/100 | Training Loss: 0.538 | Valid Score: 0.608
#
# Epoch: 7/100 | Best Valid Score Until Now: 0.608
#
# Save checkpoint
# Epoch: 8/100 | Training Loss: 0.527 | Valid Score: 0.628
#
# Epoch: 8/100 | Best Valid Score Until Now: 0.628
#
# Save checkpoint
# Epoch: 9/100 | Training Loss: 0.516 | Valid Score: 0.643
#
# Epoch: 9/100 | Best Valid Score Until Now: 0.643
#
# Save checkpoint
# Epoch: 10/100 | Training Loss: 0.510 | Valid Score: 0.655
#
# Epoch: 10/100 | Best Valid Score Until Now: 0.655
#
# Save checkpoint
# Epoch: 11/100 | Training Loss: 0.500 | Valid Score: 0.665
#
# Epoch: 11/100 | Best Valid Score Until Now: 0.665
#
# Patience 1
# Epoch: 12/100 | Training Loss: 0.495 | Valid Score: 0.665
#
# Epoch: 12/100 | Best Valid Score Until Now: 0.665
#
# Save checkpoint
# Epoch: 13/100 | Training Loss: 0.489 | Valid Score: 0.671
#
# Epoch: 13/100 | Best Valid Score Until Now: 0.671
#
# Save checkpoint
# Epoch: 14/100 | Training Loss: 0.485 | Valid Score: 0.675
#
# Epoch: 14/100 | Best Valid Score Until Now: 0.675
#
# Patience 1
# Epoch: 15/100 | Training Loss: 0.477 | Valid Score: 0.673
#
# Epoch: 15/100 | Best Valid Score Until Now: 0.675
#
# Save checkpoint
# Epoch: 16/100 | Training Loss: 0.475 | Valid Score: 0.678
#
# Epoch: 16/100 | Best Valid Score Until Now: 0.678
#
# Patience 1
# Epoch: 17/100 | Training Loss: 0.468 | Valid Score: 0.677
#
# Epoch: 17/100 | Best Valid Score Until Now: 0.678
#
# Save checkpoint
# Epoch: 18/100 | Training Loss: 0.463 | Valid Score: 0.680
#
# Epoch: 18/100 | Best Valid Score Until Now: 0.680
#
# Save checkpoint
# Epoch: 19/100 | Training Loss: 0.461 | Valid Score: 0.687
#
# Epoch: 19/100 | Best Valid Score Until Now: 0.687
#
# Patience 1
# Epoch: 20/100 | Training Loss: 0.453 | Valid Score: 0.686
#
# Epoch: 20/100 | Best Valid Score Until Now: 0.687
#
# Save checkpoint
# Epoch: 21/100 | Training Loss: 0.453 | Valid Score: 0.692
#
# Epoch: 21/100 | Best Valid Score Until Now: 0.692
#
# Save checkpoint
# Epoch: 22/100 | Training Loss: 0.450 | Valid Score: 0.694
#
# Epoch: 22/100 | Best Valid Score Until Now: 0.694
#
# Save checkpoint
# Epoch: 23/100 | Training Loss: 0.446 | Valid Score: 0.697
#
# Epoch: 23/100 | Best Valid Score Until Now: 0.697
#
# Save checkpoint
# Epoch: 24/100 | Training Loss: 0.444 | Valid Score: 0.699
#
# Epoch: 24/100 | Best Valid Score Until Now: 0.699
#
# Save checkpoint
# Epoch: 25/100 | Training Loss: 0.441 | Valid Score: 0.703
#
# Epoch: 25/100 | Best Valid Score Until Now: 0.703
#
# Save checkpoint
# Epoch: 26/100 | Training Loss: 0.438 | Valid Score: 0.704
#
# Epoch: 26/100 | Best Valid Score Until Now: 0.704
#
# Save checkpoint
# Epoch: 27/100 | Training Loss: 0.435 | Valid Score: 0.707
#
# Epoch: 27/100 | Best Valid Score Until Now: 0.707
#
# Save checkpoint
# Epoch: 28/100 | Training Loss: 0.435 | Valid Score: 0.709
#
# Epoch: 28/100 | Best Valid Score Until Now: 0.709
#
# Save checkpoint
# Epoch: 29/100 | Training Loss: 0.430 | Valid Score: 0.712
#
# Epoch: 29/100 | Best Valid Score Until Now: 0.712
#
# Save checkpoint
# Epoch: 30/100 | Training Loss: 0.431 | Valid Score: 0.712
#
# Epoch: 30/100 | Best Valid Score Until Now: 0.712
#
# Save checkpoint
# Epoch: 31/100 | Training Loss: 0.428 | Valid Score: 0.713
#
# Epoch: 31/100 | Best Valid Score Until Now: 0.713
#
# Save checkpoint
# Epoch: 32/100 | Training Loss: 0.425 | Valid Score: 0.718
#
# Epoch: 32/100 | Best Valid Score Until Now: 0.718
#
# Patience 1
# Epoch: 33/100 | Training Loss: 0.421 | Valid Score: 0.717
#
# Epoch: 33/100 | Best Valid Score Until Now: 0.718
#
# Save checkpoint
# Epoch: 34/100 | Training Loss: 0.422 | Valid Score: 0.720
#
# Epoch: 34/100 | Best Valid Score Until Now: 0.720
#
# Save checkpoint
# Epoch: 35/100 | Training Loss: 0.416 | Valid Score: 0.723
#
# Epoch: 35/100 | Best Valid Score Until Now: 0.723
#
# Save checkpoint
# Epoch: 36/100 | Training Loss: 0.419 | Valid Score: 0.726
#
# Epoch: 36/100 | Best Valid Score Until Now: 0.726
#
# Patience 1
# Epoch: 37/100 | Training Loss: 0.416 | Valid Score: 0.724
#
# Epoch: 37/100 | Best Valid Score Until Now: 0.726
#
# Patience 2
# Epoch: 38/100 | Training Loss: 0.415 | Valid Score: 0.725
#
# Epoch: 38/100 | Best Valid Score Until Now: 0.726
#
# Save checkpoint
# Epoch: 39/100 | Training Loss: 0.414 | Valid Score: 0.732
#
# Epoch: 39/100 | Best Valid Score Until Now: 0.732
#
# Patience 1
# Epoch: 40/100 | Training Loss: 0.414 | Valid Score: 0.729
#
# Epoch: 40/100 | Best Valid Score Until Now: 0.732
#
# Patience 2
# Epoch: 41/100 | Training Loss: 0.409 | Valid Score: 0.730
#
# Epoch: 41/100 | Best Valid Score Until Now: 0.732
#
# Save checkpoint
# Epoch: 42/100 | Training Loss: 0.408 | Valid Score: 0.734
#
# Epoch: 42/100 | Best Valid Score Until Now: 0.734
#
# Patience 1
# Epoch: 43/100 | Training Loss: 0.406 | Valid Score: 0.732
#
# Epoch: 43/100 | Best Valid Score Until Now: 0.734
#
# Save checkpoint
# Epoch: 44/100 | Training Loss: 0.407 | Valid Score: 0.734
#
# Epoch: 44/100 | Best Valid Score Until Now: 0.734
#
# Save checkpoint
# Epoch: 45/100 | Training Loss: 0.399 | Valid Score: 0.740
#
# Epoch: 45/100 | Best Valid Score Until Now: 0.740
#
# Patience 1
# Epoch: 46/100 | Training Loss: 0.406 | Valid Score: 0.739
#
# Epoch: 46/100 | Best Valid Score Until Now: 0.740
#
# Save checkpoint
# Epoch: 47/100 | Training Loss: 0.407 | Valid Score: 0.740
#
# Epoch: 47/100 | Best Valid Score Until Now: 0.740
#
# Save checkpoint
# Epoch: 48/100 | Training Loss: 0.402 | Valid Score: 0.744
#
# Epoch: 48/100 | Best Valid Score Until Now: 0.744
#
# Save checkpoint
# Epoch: 49/100 | Training Loss: 0.404 | Valid Score: 0.747
#
# Epoch: 49/100 | Best Valid Score Until Now: 0.747
#
# Patience 1
# Epoch: 50/100 | Training Loss: 0.403 | Valid Score: 0.746
#
# Epoch: 50/100 | Best Valid Score Until Now: 0.747
#
# Save checkpoint
# Epoch: 51/100 | Training Loss: 0.402 | Valid Score: 0.751
#
# Epoch: 51/100 | Best Valid Score Until Now: 0.751
#
# Patience 1
# Epoch: 52/100 | Training Loss: 0.399 | Valid Score: 0.749
#
# Epoch: 52/100 | Best Valid Score Until Now: 0.751
#
# Save checkpoint
# Epoch: 53/100 | Training Loss: 0.399 | Valid Score: 0.753
#
# Epoch: 53/100 | Best Valid Score Until Now: 0.753
#
# Save checkpoint
# Epoch: 54/100 | Training Loss: 0.397 | Valid Score: 0.754
#
# Epoch: 54/100 | Best Valid Score Until Now: 0.754
#
# Patience 1
# Epoch: 55/100 | Training Loss: 0.397 | Valid Score: 0.753
#
# Epoch: 55/100 | Best Valid Score Until Now: 0.754
#
# Save checkpoint
# Epoch: 56/100 | Training Loss: 0.399 | Valid Score: 0.759
#
# Epoch: 56/100 | Best Valid Score Until Now: 0.759
#
# Patience 1
# Epoch: 57/100 | Training Loss: 0.399 | Valid Score: 0.758
#
# Epoch: 57/100 | Best Valid Score Until Now: 0.759
#
# Save checkpoint
# Epoch: 58/100 | Training Loss: 0.397 | Valid Score: 0.760
#
# Epoch: 58/100 | Best Valid Score Until Now: 0.760
#
# Save checkpoint
# Epoch: 59/100 | Training Loss: 0.394 | Valid Score: 0.761
#
# Epoch: 59/100 | Best Valid Score Until Now: 0.761
#
# Save checkpoint
# Epoch: 60/100 | Training Loss: 0.396 | Valid Score: 0.761
#
# Epoch: 60/100 | Best Valid Score Until Now: 0.761
#
# Save checkpoint
# Epoch: 61/100 | Training Loss: 0.395 | Valid Score: 0.764
#
# Epoch: 61/100 | Best Valid Score Until Now: 0.764
#
# Patience 1
# Epoch: 62/100 | Training Loss: 0.391 | Valid Score: 0.763
#
# Epoch: 62/100 | Best Valid Score Until Now: 0.764
#
# Save checkpoint
# Epoch: 63/100 | Training Loss: 0.389 | Valid Score: 0.765
#
# Epoch: 63/100 | Best Valid Score Until Now: 0.765
#
# Save checkpoint
# Epoch: 64/100 | Training Loss: 0.394 | Valid Score: 0.770
#
# Epoch: 64/100 | Best Valid Score Until Now: 0.770
#
# Patience 1
# Epoch: 65/100 | Training Loss: 0.393 | Valid Score: 0.766
#
# Epoch: 65/100 | Best Valid Score Until Now: 0.770
#
# Patience 2
# Epoch: 66/100 | Training Loss: 0.387 | Valid Score: 0.768
#
# Epoch: 66/100 | Best Valid Score Until Now: 0.770
#
# Patience 3
# Epoch: 67/100 | Training Loss: 0.390 | Valid Score: 0.768
#
# Epoch: 67/100 | Best Valid Score Until Now: 0.770
#
# Save checkpoint
# Epoch: 68/100 | Training Loss: 0.391 | Valid Score: 0.772
#
# Epoch: 68/100 | Best Valid Score Until Now: 0.772
#
# Save checkpoint
# Epoch: 69/100 | Training Loss: 0.389 | Valid Score: 0.772
#
# Epoch: 69/100 | Best Valid Score Until Now: 0.772
#
# Save checkpoint
# Epoch: 70/100 | Training Loss: 0.388 | Valid Score: 0.773
#
# Epoch: 70/100 | Best Valid Score Until Now: 0.773
#
# Save checkpoint
# Epoch: 71/100 | Training Loss: 0.388 | Valid Score: 0.776
#
# Epoch: 71/100 | Best Valid Score Until Now: 0.776
#
# Patience 1
# Epoch: 72/100 | Training Loss: 0.385 | Valid Score: 0.776
#
# Epoch: 72/100 | Best Valid Score Until Now: 0.776
#
# Save checkpoint
# Epoch: 73/100 | Training Loss: 0.386 | Valid Score: 0.778
#
# Epoch: 73/100 | Best Valid Score Until Now: 0.778
#
# Save checkpoint
# Epoch: 74/100 | Training Loss: 0.386 | Valid Score: 0.779
#
# Epoch: 74/100 | Best Valid Score Until Now: 0.779
#
# Patience 1
# Epoch: 75/100 | Training Loss: 0.381 | Valid Score: 0.779
#
# Epoch: 75/100 | Best Valid Score Until Now: 0.779
#
# Save checkpoint
# Epoch: 76/100 | Training Loss: 0.386 | Valid Score: 0.780
#
# Epoch: 76/100 | Best Valid Score Until Now: 0.780
#
# Patience 1
# Epoch: 77/100 | Training Loss: 0.385 | Valid Score: 0.780
#
# Epoch: 77/100 | Best Valid Score Until Now: 0.780
#
# Save checkpoint
# Epoch: 78/100 | Training Loss: 0.385 | Valid Score: 0.782
#
# Epoch: 78/100 | Best Valid Score Until Now: 0.782
#
# Save checkpoint
# Epoch: 79/100 | Training Loss: 0.384 | Valid Score: 0.783
#
# Epoch: 79/100 | Best Valid Score Until Now: 0.783
#
# Save checkpoint
# Epoch: 80/100 | Training Loss: 0.382 | Valid Score: 0.785
#
# Epoch: 80/100 | Best Valid Score Until Now: 0.785
#
# Save checkpoint
# Epoch: 81/100 | Training Loss: 0.383 | Valid Score: 0.786
#
# Epoch: 81/100 | Best Valid Score Until Now: 0.786
#
# Patience 1
# Epoch: 82/100 | Training Loss: 0.383 | Valid Score: 0.785
#
# Epoch: 82/100 | Best Valid Score Until Now: 0.786
#
# Save checkpoint
# Epoch: 83/100 | Training Loss: 0.380 | Valid Score: 0.789
#
# Epoch: 83/100 | Best Valid Score Until Now: 0.789
#
# Patience 1
# Epoch: 84/100 | Training Loss: 0.380 | Valid Score: 0.789
#
# Epoch: 84/100 | Best Valid Score Until Now: 0.789
#
# Patience 2
# Epoch: 85/100 | Training Loss: 0.379 | Valid Score: 0.789
#
# Epoch: 85/100 | Best Valid Score Until Now: 0.789
#
# Save checkpoint
# Epoch: 86/100 | Training Loss: 0.382 | Valid Score: 0.791
#
# Epoch: 86/100 | Best Valid Score Until Now: 0.791
#
# Save checkpoint
# Epoch: 87/100 | Training Loss: 0.381 | Valid Score: 0.794
#
# Epoch: 87/100 | Best Valid Score Until Now: 0.794
#
# Patience 1
# Epoch: 88/100 | Training Loss: 0.378 | Valid Score: 0.792
#
# Epoch: 88/100 | Best Valid Score Until Now: 0.794
#
# Save checkpoint
# Epoch: 89/100 | Training Loss: 0.380 | Valid Score: 0.794
#
# Epoch: 89/100 | Best Valid Score Until Now: 0.794
#
# Save checkpoint
# Epoch: 90/100 | Training Loss: 0.378 | Valid Score: 0.796
#
# Epoch: 90/100 | Best Valid Score Until Now: 0.796
#
# Save checkpoint
# Epoch: 91/100 | Training Loss: 0.380 | Valid Score: 0.797
#
# Epoch: 91/100 | Best Valid Score Until Now: 0.797
#
# Save checkpoint
# Epoch: 92/100 | Training Loss: 0.379 | Valid Score: 0.797
#
# Epoch: 92/100 | Best Valid Score Until Now: 0.797
#
# Save checkpoint
# Epoch: 93/100 | Training Loss: 0.378 | Valid Score: 0.800
#
# Epoch: 93/100 | Best Valid Score Until Now: 0.800
#
# Patience 1
# Epoch: 94/100 | Training Loss: 0.379 | Valid Score: 0.800
#
# Epoch: 94/100 | Best Valid Score Until Now: 0.800
#
# Save checkpoint
# Epoch: 95/100 | Training Loss: 0.376 | Valid Score: 0.802
#
# Epoch: 95/100 | Best Valid Score Until Now: 0.802
#
# Save checkpoint
# Epoch: 96/100 | Training Loss: 0.376 | Valid Score: 0.802
#
# Epoch: 96/100 | Best Valid Score Until Now: 0.802
#
# Patience 1
# Epoch: 97/100 | Training Loss: 0.376 | Valid Score: 0.802
#
# Epoch: 97/100 | Best Valid Score Until Now: 0.802
#
# Save checkpoint
# Epoch: 98/100 | Training Loss: 0.377 | Valid Score: 0.803
#
# Epoch: 98/100 | Best Valid Score Until Now: 0.803
#
# Save checkpoint
# Epoch: 99/100 | Training Loss: 0.376 | Valid Score: 0.804
#
# Epoch: 99/100 | Best Valid Score Until Now: 0.804
#
# Patience 1
# Epoch: 100/100 | Training Loss: 0.378 | Valid Score: 0.803
#
# Epoch: 100/100 | Best Valid Score Until Now: 0.804
#
# Final results:
# Average Valid Score: 0.804
#
# Test Score: 0.789
#
# Execution time: 67.733 seconds
